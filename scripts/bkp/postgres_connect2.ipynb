# %%
from pyspark.sql import SparkSession

# %%
# Initialize SparkSession
spark = SparkSession.builder \
    .appName('postgresql_connection') \
    .getOrCreate()

# %%
# PostgreSQL connection parameters
database = "skyminyr_development"
user = "postgres"
password = "password"
url = f"jdbc:postgresql://global-db:5432/{database}"

# %%
# Read table names from PostgreSQL metadata
table_names = spark.read \
    .format("jdbc") \
    .option("url", url) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "org.postgresql.Driver") \
    .option("dbtable", "(SELECT table_name FROM information_schema.tables WHERE table_schema = 'public') as tables") \
    .load()

# %%
# Convert the DataFrame to a list of table names
table_list = table_names.select("table_name").rdd.flatMap(lambda x: x).collect()

# Print the list of table names
print("Available Tables:")
for table_name in table_list:
    print(table_name)

# Now you can use this list to access each table individually
# Out:
# Available Tables:
# ar_internal_metadata
# companies
# company_annual_revenues
# company_customers
# company_events
# company_funding_round_investors
# company_funding_rounds
# company_headcounts
# company_locations
# company_names
# company_sectors
# company_social_urls
# company_stock_tickers
# people
# person_customers
# person_educations
# person_employments
# person_social_urls
# schema_migrations

# %%
# Function to load data from a table into a DataFrame
def load_table(table_name):
    df = spark.read \
        .format("jdbc") \
        .option("url", url) \
        .option("dbtable", table_name) \
        .option("user", user) \
        .option("password", password) \
        .option("driver", "org.postgresql.Driver") \
        .load()
    return df

# Load data from the "people" table into a DataFrame
people_df = load_table("people")

people_df.show(5)
people_df = people_df.withColumnRenamed("address", "address_ppl")
people_df = people_df.withColumnRenamed("id", "person_id_ppl")
people_df = people_df.withColumnRenamed("created_at", "created_at_ppl")
people_df = people_df.withColumnRenamed("updated_at", "updated_at_ppl")
people_df.show(5)
# Out:
# +---------+-----------------+--------------------+--------------------+-------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |       id|             name|        linkedin_url|           photo_url|address|       city|        region|postal_code|country|company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|          created_at|          updated_at|
# +---------+-----------------+--------------------+--------------------+-------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |693540132|  Lika Razac-Ince|https://www.linke...|https://media-exp...|   NULL|       NULL|          NULL|       NULL|   NULL|        NULL|           NULL|Two sides of a co...|Professional Phot...|Content & Product...|2018-04-01|      NULL|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |118418234|   Kenny Sheridan|https://www.linke...|https://static.li...|   NULL|    Merrick|      New York|       NULL|     US|        NULL|           NULL|                NULL|     General Manager|Manager at Apple ...|2011-01-01|2012-01-01|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# | 64876372|      David Coyle|https://www.linke...|https://static.li...|   NULL|       Apex|North Carolina|       NULL|     US| Realtor.com|           NULL|IT professional w...|Principal iOS Arc...|Sr. iOS Engineer ...|2015-04-01|2018-05-01|     12942|2023-12-11 06:18:...|2023-10-26 15:57:...|
# | 67121188|   Gurpreet Singh|https://www.linke...|https://static.li...|   NULL|San Antonio|         Texas|       NULL|     US|       Apple|           NULL|Innovative and ch...|Sr Technical Proj...|Sr Technical Prog...|2019-02-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-26 15:57:...|
# | 57288072|Anthony Salvaggio|https://www.linke...|https://media-exp...|   NULL|     Marion|      New York|       NULL|     US|     Verizon|           NULL|A skilled communi...|   Acting Supervisor| Carpe Facto @ Apple|2012-01-01|2013-01-01|      4096|2023-12-11 06:18:...|2023-10-26 15:57:...|
# +---------+-----------------+--------------------+--------------------+-------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# only showing top 5 rows
#
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |person_id_ppl|             name|        linkedin_url|           photo_url|address_ppl|       city|        region|postal_code|country|company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |    693540132|  Lika Razac-Ince|https://www.linke...|https://media-exp...|       NULL|       NULL|          NULL|       NULL|   NULL|        NULL|           NULL|Two sides of a co...|Professional Phot...|Content & Product...|2018-04-01|      NULL|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |    118418234|   Kenny Sheridan|https://www.linke...|https://static.li...|       NULL|    Merrick|      New York|       NULL|     US|        NULL|           NULL|                NULL|     General Manager|Manager at Apple ...|2011-01-01|2012-01-01|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     64876372|      David Coyle|https://www.linke...|https://static.li...|       NULL|       Apex|North Carolina|       NULL|     US| Realtor.com|           NULL|IT professional w...|Principal iOS Arc...|Sr. iOS Engineer ...|2015-04-01|2018-05-01|     12942|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     67121188|   Gurpreet Singh|https://www.linke...|https://static.li...|       NULL|San Antonio|         Texas|       NULL|     US|       Apple|           NULL|Innovative and ch...|Sr Technical Proj...|Sr Technical Prog...|2019-02-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     57288072|Anthony Salvaggio|https://www.linke...|https://media-exp...|       NULL|     Marion|      New York|       NULL|     US|     Verizon|           NULL|A skilled communi...|   Acting Supervisor| Carpe Facto @ Apple|2012-01-01|2013-01-01|      4096|2023-12-11 06:18:...|2023-10-26 15:57:...|
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# only showing top 5 rows

# %%
person_customer_df = load_table("person_customers")
person_customer_df = person_customer_df.withColumnRenamed("person_id", "person_id_pc")
person_customer_df = person_customer_df.withColumnRenamed("created_at", "created_at_pc")
person_customer_df = person_customer_df.withColumnRenamed("updated_at", "updated_at_pc")
person_customer_df = person_customer_df.withColumnRenamed("id", "id_pc")
person_customer_df.show(5)
# Out:
# +-----+------------+--------------------+--------------------+--------------------+
# |id_pc|person_id_pc|         customer_id|       created_at_pc|       updated_at_pc|
# +-----+------------+--------------------+--------------------+--------------------+
# |    1|   693540132|14b76a2f-4545-4fb...|2023-12-18 11:12:...|2023-12-18 11:12:...|
# |    2|    52762066|7538cb11-1c23-4c7...|2024-01-08 12:16:...|2024-01-08 12:16:...|
# |    3|     1567835|7538cb11-1c23-4c7...|2024-01-16 13:22:...|2024-01-16 13:22:...|
# |    4|    16135235|7538cb11-1c23-4c7...|2024-01-16 13:26:...|2024-01-16 13:26:...|
# |    5|    48171849|7538cb11-1c23-4c7...|2024-01-16 13:29:...|2024-01-16 13:29:...|
# +-----+------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import count
#filt_df = person_customer_df.where(person_customer_df.person_id_pc == 693540132)
#filt_df.show()

# %%
# Group by person_id and count the occurrences
grouped_df = person_customer_df.groupBy("person_id_pc").agg(count("*").alias("count"))


# Filter rows with count > 1
filtered_df = grouped_df.filter(grouped_df["count"] > 1)
filtered_df.show(5)

# Join with original DataFrame to get the rows
result_df = person_customer_df.join(filtered_df, "person_id_pc", "inner")

# Show the result
result_df.show()
# Out:
# +------------+-----+
# |person_id_pc|count|
# +------------+-----+
# |   693540132|    2|
# +------------+-----+
#
# +------------+-----+--------------------+--------------------+--------------------+-----+
# |person_id_pc|id_pc|         customer_id|       created_at_pc|       updated_at_pc|count|
# +------------+-----+--------------------+--------------------+--------------------+-----+
# |   693540132|    6|7538cb11-1c23-4c7...|2024-01-19 10:13:...|2024-01-19 10:13:...|    2|
# |   693540132|    1|14b76a2f-4545-4fb...|2023-12-18 11:12:...|2023-12-18 11:12:...|    2|
# +------------+-----+--------------------+--------------------+--------------------+-----+

# %%
person_customer_df.show(5)
#filt_df = person_customer_df.where(person_customer_df.person_id_pc == 693540132)
#filt_df.show()
# Out:
# +-----+------------+--------------------+--------------------+--------------------+
# |id_pc|person_id_pc|         customer_id|       created_at_pc|       updated_at_pc|
# +-----+------------+--------------------+--------------------+--------------------+
# |    1|   693540132|14b76a2f-4545-4fb...|2023-12-18 11:12:...|2023-12-18 11:12:...|
# |    2|    52762066|7538cb11-1c23-4c7...|2024-01-08 12:16:...|2024-01-08 12:16:...|
# |    3|     1567835|7538cb11-1c23-4c7...|2024-01-16 13:22:...|2024-01-16 13:22:...|
# |    4|    16135235|7538cb11-1c23-4c7...|2024-01-16 13:26:...|2024-01-16 13:26:...|
# |    5|    48171849|7538cb11-1c23-4c7...|2024-01-16 13:29:...|2024-01-16 13:29:...|
# +-----+------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

# Group by "person_id" and concatenate values of other columns
unique_person_customer_df = person_customer_df.groupBy("person_id_pc").agg(
    F.concat_ws(",", F.collect_list("created_at_pc")).alias("created_at_pc"),
    F.concat_ws(",", F.collect_list("customer_id")).alias("customer_id_pc"),
    F.concat_ws(",", F.collect_list("id_pc")).alias("id_pc"),
    F.concat_ws(",", F.collect_list("updated_at_pc")).alias("updated_at_pc")
)

# # Show the unique DataFrame
unique_person_customer_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|
# +------------+--------------------+--------------------+-----+--------------------+
# |      101255|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    7|2024-02-07 11:24:...|
# |      124469|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    8|2024-02-07 11:24:...|
# |      149312|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    9|2024-02-07 11:24:...|
# |      175688|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   10|2024-02-07 11:24:...|
# |      225814|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   11|2024-02-07 11:24:...|
# +------------+--------------------+--------------------+-----+--------------------+
# only showing top 5 rows

# %%
# # Filter the unique DataFrame for person_id 693540132
# specific_person_df = unique_person_customer_df.filter(unique_person_customer_df["person_id"] == "693540132")

# # Show the DataFrame for person_id 693540132
# specific_person_df.show(truncate=False)

# %%
# Count the distinct occurrences of person_id
distinct_count = unique_person_customer_df.select("person_id_pc").distinct().count()

# Count the total number of rows in the DataFrame
total_rows = unique_person_customer_df.count()

# Check if the DataFrame is unique based on person_id
if distinct_count == total_rows:
    print("DataFrame is unique based on person_id_pc")
else:
    print("DataFrame is not unique based on person_id_pc")
# Out:
# DataFrame is unique based on person_id_pc

# %%
unique_person_customer_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|
# +------------+--------------------+--------------------+-----+--------------------+
# |      101255|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    7|2024-02-07 11:24:...|
# |      124469|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    8|2024-02-07 11:24:...|
# |      149312|2024-02-07 11:24:...|7538cb11-1c23-4c7...|    9|2024-02-07 11:24:...|
# |      175688|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   10|2024-02-07 11:24:...|
# |      225814|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   11|2024-02-07 11:24:...|
# +------------+--------------------+--------------------+-----+--------------------+
# only showing top 5 rows

# %%
people_df.show(5)
# Out:
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |person_id_ppl|             name|        linkedin_url|           photo_url|address_ppl|       city|        region|postal_code|country|company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |    693540132|  Lika Razac-Ince|https://www.linke...|https://media-exp...|       NULL|       NULL|          NULL|       NULL|   NULL|        NULL|           NULL|Two sides of a co...|Professional Phot...|Content & Product...|2018-04-01|      NULL|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |    118418234|   Kenny Sheridan|https://www.linke...|https://static.li...|       NULL|    Merrick|      New York|       NULL|     US|        NULL|           NULL|                NULL|     General Manager|Manager at Apple ...|2011-01-01|2012-01-01|      NULL|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     64876372|      David Coyle|https://www.linke...|https://static.li...|       NULL|       Apex|North Carolina|       NULL|     US| Realtor.com|           NULL|IT professional w...|Principal iOS Arc...|Sr. iOS Engineer ...|2015-04-01|2018-05-01|     12942|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     67121188|   Gurpreet Singh|https://www.linke...|https://static.li...|       NULL|San Antonio|         Texas|       NULL|     US|       Apple|           NULL|Innovative and ch...|Sr Technical Proj...|Sr Technical Prog...|2019-02-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |     57288072|Anthony Salvaggio|https://www.linke...|https://media-exp...|       NULL|     Marion|      New York|       NULL|     US|     Verizon|           NULL|A skilled communi...|   Acting Supervisor| Carpe Facto @ Apple|2012-01-01|2013-01-01|      4096|2023-12-11 06:18:...|2023-10-26 15:57:...|
# +-------------+-----------------+--------------------+--------------------+-----------+-----------+--------------+-----------+-------+------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Join people_df and unique_person_customer_df based on person_id of unique_person_customer_df and id of people_df
person_customer_joined_df = unique_person_customer_df.join(
    people_df,
    unique_person_customer_df["person_id_pc"] == people_df["person_id_ppl"],
    "inner"
)

# Show the joined DataFrame
person_customer_joined_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+-----------------+--------------------+--------------------+-----------+------+------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|             name|        linkedin_url|           photo_url|address_ppl|  city|region|postal_code|  country|    company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|
# +------------+--------------------+--------------------+-----+--------------------+-------------+-----------------+--------------------+--------------------+-----------+------+------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|      Vivian Weng|https://www.linke...|https://media-exp...|       NULL|  NULL|  NULL|       NULL|SINGAPORE|        DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|
# |   902184389|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   99|2024-02-09 12:08:...|    902184389|Hendrik Bourgeois|https://www.linke...|https://media-exp...|       NULL|  NULL|  NULL|       NULL|     NULL|General Electric|           NULL|                NULL|General Counsel, ...|Head of Governmen...|2009-04-01|2011-06-01|      2025|2023-12-11 06:18:...|2023-10-26 15:57:...|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849|  Courtney Turner|https://www.linke...|https://static-ex...|       NULL|Toledo|  Ohio|       NULL|       US|           Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|    Katie Richter|https://www.linke...|https://static-ex...|       NULL|Austin| Texas|       NULL|       US|Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|
# |   787025923|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   58|2024-02-09 12:07:...|    787025923|      Lynda Zhang|https://www.linke...|https://media-exp...|       NULL|  NULL|  NULL|       NULL|     NULL|            IKEA|        Manager|                NULL|Beijing Shopping ...|Retail Ownership ...|2011-10-01|2012-12-01|    256241|2023-12-11 06:18:...|2023-10-26 15:57:...|
# +------------+--------------------+--------------------+-----+--------------------+-------------+-----------------+--------------------+--------------------+-----------+------+------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+
# only showing top 5 rows

# %%
person_educations_df = load_table("person_educations")
person_educations_df.show(5)
person_educations_df =person_educations_df.withColumnRenamed("person_id","person_id_ped")
person_educations_df.show(5)
# Out:
# +-----+---------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# |   id|person_id|institution_id|    institution_name|              degree|           subject|started_on|  ended_on|          created_at|updated_at|
# +-----+---------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# |12091| 64876372|          NULL|University Of Win...|Bachelors;Bachelo...|           Geology|1980-01-01|1984-01-01|2023-12-11 06:18:...|      NULL|
# |12092| 64876372|          NULL|University Of Win...|Master Of Science...|           Geology|1984-01-01|1986-01-01|2023-12-11 06:18:...|      NULL|
# |12093| 64876372|          NULL| La Trobe University|Doctorates;Doctor...|     Earth Science|1988-01-01|1992-01-01|2023-12-11 06:18:...|      NULL|
# |12094| 67121188|       8522590|Keller Graduate S...|                NULL|Project Management|2013-01-01|2015-01-01|2023-12-11 06:18:...|      NULL|
# |12095| 67121188|        197284|Sam Houston State...|Master Of Busines...|        Management|2010-01-01|2012-01-01|2023-12-11 06:18:...|      NULL|
# +-----+---------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# only showing top 5 rows
#
# +-----+-------------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# |   id|person_id_ped|institution_id|    institution_name|              degree|           subject|started_on|  ended_on|          created_at|updated_at|
# +-----+-------------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# |12091|     64876372|          NULL|University Of Win...|Bachelors;Bachelo...|           Geology|1980-01-01|1984-01-01|2023-12-11 06:18:...|      NULL|
# |12092|     64876372|          NULL|University Of Win...|Master Of Science...|           Geology|1984-01-01|1986-01-01|2023-12-11 06:18:...|      NULL|
# |12093|     64876372|          NULL| La Trobe University|Doctorates;Doctor...|     Earth Science|1988-01-01|1992-01-01|2023-12-11 06:18:...|      NULL|
# |12094|     67121188|       8522590|Keller Graduate S...|                NULL|Project Management|2013-01-01|2015-01-01|2023-12-11 06:18:...|      NULL|
# |12095|     67121188|        197284|Sam Houston State...|Master Of Busines...|        Management|2010-01-01|2012-01-01|2023-12-11 06:18:...|      NULL|
# +-----+-------------+--------------+--------------------+--------------------+------------------+----------+----------+--------------------+----------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

# Define a struct for each institute
institute_struct = F.struct(
    "institution_id", "institution_name", "degree", "subject", "started_on", "ended_on"
)

# Group by person_id and collect list of institute details as structs
grouped_educations_df = person_educations_df.groupBy("person_id_ped").agg(
    F.collect_list(institute_struct).alias("institute"), 
    # ("institute - (institution_id, institution_name, degree, subject, started_on, ended_on)"),
    F.max("created_at").alias("latest_edu_created_at"),
    F.max("updated_at").alias("latest_edu_updated_at")
)

# Show the result
grouped_educations_df.show(5,truncate=False)
# Out:
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |person_id_ped|institute                                                                                                                                                                                                                                                                  |latest_edu_created_at     |latest_edu_updated_at|
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |101255       |[{117741, University of Utah, BS, CS, NULL, 1982-01-01}]                                                                                                                                                                                                                   |2023-12-11 06:18:37.445885|NULL                 |
# |124469       |[{191937, Politehnica University of Bucharest, Master's degree, Computer Science, 2004-01-01, 2009-01-01}, {121901, University Of Montpellier, PhD, Artificial Intelligence, 2009-01-01, 2012-01-01}]                                                                      |2023-12-11 06:18:37.445885|NULL                 |
# |149312       |[{NULL, State University of New York at Buffalo, MFA, Media Arts Production, 2002-01-01, 2006-01-01}, {195673, University of Idaho, MA, English, Literature, 1999-01-01, 2001-01-01}, {195673, University of Idaho, BA, English, Creative Writing, 1994-01-01, 1999-01-01}]|2023-12-11 06:18:37.445885|NULL                 |
# |225814       |[{201288, University of Pennsylvania, Graduate, unknown, NULL, NULL}, {75977, Columbia University, Master's, Journalism, NULL, NULL}]                                                                                                                                      |2023-12-11 06:18:37.445885|NULL                 |
# |227168       |[{196339, University of Ferrara, unknown, unknown, NULL, NULL}]                                                                                                                                                                                                            |2023-12-11 06:18:37.445885|NULL                 |
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# only showing top 5 rows

# %%
# Count the distinct occurrences of person_id
distinct_count = grouped_educations_df.select("person_id_ped").distinct().count()

# Count the total number of rows in the DataFrame
total_rows = grouped_educations_df.count()

# Check if the DataFrame is unique based on person_id
if distinct_count == total_rows:
    print("DataFrame is unique based on person_id")
else:
    print("DataFrame is not unique based on person_id")
# Out:
# DataFrame is unique based on person_id

# %%
from pyspark.sql.functions import col
# Set the option to display without truncation
spark.conf.set("spark.sql.repl.eagerEval.enabled", True)

# Filter the DataFrame to select rows where person_id_ped = 64876372
filtered_df = grouped_educations_df.filter(col("person_id_ped") == 64876372)

# Show the DataFrame
filtered_df.show(truncate=False)
# Out:
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |person_id_ped|institute                                                                                                                                                                                                                                                                                      |latest_edu_created_at     |latest_edu_updated_at|
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |64876372     |[{NULL, University Of Windsor, Bachelors;Bachelor Of Science, Geology, 1980-01-01, 1984-01-01}, {NULL, University Of Windsor, Master Of Science;Masters, Geology, 1984-01-01, 1986-01-01}, {NULL, La Trobe University, Doctorates;Doctor Of Philosophy, Earth Science, 1988-01-01, 1992-01-01}]|2023-12-11 06:18:37.445885|NULL                 |
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+

# %%
# Join people_people_customer_joined_df and grouped_educations_df based on person_id
person_customer_education_joined_df = person_customer_joined_df.join(
    grouped_educations_df,
    person_customer_joined_df.person_id_pc == grouped_educations_df.person_id_ped,
    "inner"
)

# # Add filter to remove rows where Institute column is null
person_customer_education_joined_df = person_customer_education_joined_df.filter(
    col("institute").isNotNull()
).drop(grouped_educations_df.person_id_ped)

# Show the result
person_customer_education_joined_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+--------------------+--------------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|           name|        linkedin_url|           photo_url|address_ppl|   city|  region|postal_code|  country|    company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|           institute|latest_edu_created_at|latest_edu_updated_at|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+--------------------+--------------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|    Vivian Weng|https://www.linke...|https://media-exp...|       NULL|   NULL|    NULL|       NULL|SINGAPORE|        DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849|Courtney Turner|https://www.linke...|https://static-ex...|       NULL| Toledo|    Ohio|       NULL|       US|           Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, The Unive...| 2023-12-11 06:18:...|                 NULL|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|  Katie Richter|https://www.linke...|https://static-ex...|       NULL| Austin|   Texas|       NULL|       US|Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Rhodes Co...| 2023-12-11 06:18:...|                 NULL|
# |     1373896|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   40|2024-02-07 11:24:...|      1373896|Chelsea Kanduth|https://www.linke...|https://static-ex...|       NULL|Chicago|Illinois|       NULL|       US|     Red Lobster|           NULL|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|2014-05-01|2015-12-01|    429133|2023-12-11 06:18:...|2023-10-26 15:57:...|[{6356260, St. Cl...| 2023-12-11 06:18:...|                 NULL|
# |    51432999|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  105|2024-02-09 12:08:...|     51432999|   Juan Sanchez|https://www.linke...|https://static-ex...|       NULL|  Boise|   Idaho|       NULL|       US|           Apple|       Director|Art Director at A...|        Art Director|                NULL|      NULL|      NULL|      1660|2023-12-11 06:18:...|2023-10-18 23:07:...|[{NULL, Minico Hi...| 2023-12-11 06:18:...|                 NULL|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+--------------------+--------------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+
# only showing top 5 rows

# %%
# Drop the specified columns
person_customer_education_joined_df = person_customer_education_joined_df.drop("linkedin_url", "photo_url")

# Show the trimmed DataFrame
person_customer_education_joined_df.show(5, truncate=False)
# Out:
# +------------+--------------------------+------------------------------------+-----+--------------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------+-----------------------------------------------------------------+----------+----------+----------+-------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |person_id_pc|created_at_pc             |customer_id_pc                      |id_pc|updated_at_pc             |person_id_ppl|name           |address_ppl|city   |region  |postal_code|country  |company_name    |seniority_level|description                                                                                                                                                                                                                                                                                                                                                                   |title                           |headline                                                         |started_on|ended_on  |company_id|created_at_ppl           |updated_at_ppl            |institute                                                                                                                                                                                                                                                                                                                    |latest_edu_created_at     |latest_edu_updated_at|
# +------------+--------------------------+------------------------------------+-----+--------------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------+-----------------------------------------------------------------+----------+----------+----------+-------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |949256266   |2024-02-09 12:07:56.872068|7538cb11-1c23-4c76-87c7-5111a0f166dc|60   |2024-02-09 12:07:56.872068|949256266    |Vivian Weng    |NULL       |NULL   |NULL    |NULL       |SINGAPORE|DBS Bank        |VP             |NULL                                                                                                                                                                                                                                                                                                                                                                          |Vice President, Innovation Group|Product Design, Strategy & Managment                             |2016-07-01|2019-04-01|15861     |2023-12-11 06:18:08.13904|NULL                      |[{NULL, University of California, Berkeley - Walter A. Haas School of Business, NULL, MBA, Finance, 2007-01-01, 2009-01-01}, {NULL, National Taiwan University, NULL, BA, International Relations, 1998-01-01, 2002-01-01}, {NULL, Yale University, NULL, MA, International Developmental Economics, 2002-01-01, 2003-01-01}]|2023-12-11 06:18:37.445885|NULL                 |
# |48171849    |2024-01-16 13:29:43.778281|7538cb11-1c23-4c76-87c7-5111a0f166dc|5    |2024-01-16 13:29:43.778281|48171849     |Courtney Turner|NULL       |Toledo |Ohio    |NULL       |US       |Apple           |NULL           |The search for something profound usually begins on a quest of "self."                                                                                                                                                                                                                                                                                                        |Creative Trainer                |NULL                                                             |2018-03-01|NULL      |1660      |2023-12-11 06:18:08.13904|2023-10-14 21:35:03.103333|[{NULL, The University Of Akron, NULL, NULL, NULL, NULL}]                                                                                                                                                                                                                                                                    |2023-12-11 06:18:37.445885|NULL                 |
# |74707094    |2024-02-09 12:08:02.438358|7538cb11-1c23-4c76-87c7-5111a0f166dc|91   |2024-02-09 12:08:02.438358|74707094     |Katie Richter  |NULL       |Austin |Texas   |NULL       |US       |Casting Networks|NULL           |Retail Business Specialist, Assistant Supervisor                                                                                                                                                                                                                                                                                                                              |BUSINESS DEVELOPMENT            |NULL                                                             |2010-05-01|2011-04-01|601281    |2023-12-11 06:18:08.13904|2023-10-14 21:35:03.103333|[{NULL, Rhodes College, Bachelors;Bachelor Of Science, Theater;Theatre, 2000-01-01, 2004-01-01}]                                                                                                                                                                                                                             |2023-12-11 06:18:37.445885|NULL                 |
# |1373896     |2024-02-07 11:24:08.05326 |7538cb11-1c23-4c76-87c7-5111a0f166dc|40   |2024-02-07 11:24:08.05326 |1373896      |Chelsea Kanduth|NULL       |Chicago|Illinois|NULL       |US       |Red Lobster     |NULL           |Experienced Account Coordinator with a demonstrated history of working in the marketing and advertising industry, focusing on providing clients with technology that best suits their needs. A creative thinker, proficient problem solver and strong communicator with a Bachelor of Science (B.S.) in Marketing from St. Cloud State University - Herberger Business School.|Front-Line Sales, Waitress      |Advertising Guru - Multi-Channel Sales Planner at Chicago Tribune|2014-05-01|2015-12-01|429133    |2023-12-11 06:18:08.13904|2023-10-26 15:57:22.35    |[{6356260, St. Cloud State University - Herberger Business School, Bachelor of Science (B.S.), Marketing, 2012-01-01, 2017-01-01}, {NULL, Griffith College (AUS), Bachelor of Science (BS), Marketing, 2016-01-01, 2016-01-01}]                                                                                              |2023-12-11 06:18:37.445885|NULL                 |
# |51432999    |2024-02-09 12:08:03.080346|7538cb11-1c23-4c76-87c7-5111a0f166dc|105  |2024-02-09 12:08:03.080346|51432999     |Juan Sanchez   |NULL       |Boise  |Idaho   |NULL       |US       |Apple           |Director       |Art Director at Apple                                                                                                                                                                                                                                                                                                                                                         |Art Director                    |NULL                                                             |NULL      |NULL      |1660      |2023-12-11 06:18:08.13904|2023-10-18 23:07:47.696666|[{NULL, Minico High School, NULL, NULL, 2011-01-01, 2014-01-01}]                                                                                                                                                                                                                                                             |2023-12-11 06:18:37.445885|NULL                 |
# +------------+--------------------------+------------------------------------+-----+--------------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------+-----------------------------------------------------------------+----------+----------+----------+-------------------------+--------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# only showing top 5 rows

# %%
person_employments_df = load_table("person_employments")
person_employments_df.show(2)
# Out:
# +-----+---------+----------+--------------------+---------------+--------------------+----------+----------+--------------------+----------+
# |   id|person_id|company_id|        company_name|seniority_level|               title|started_on|  ended_on|          created_at|updated_at|
# +-----+---------+----------+--------------------+---------------+--------------------+----------+----------+--------------------+----------+
# |78981|693540132|      NULL|                NULL|           NULL|Professional Phot...|2018-04-01|      NULL|2023-12-11 06:18:...|      NULL|
# |78982|693540132|   8911699|Interventional Pa...|    Head of ...|     Head of Digital|2006-11-01|2012-04-01|2023-12-11 06:18:...|      NULL|
# +-----+---------+----------+--------------------+---------------+--------------------+----------+----------+--------------------+----------+
# only showing top 2 rows

# %%
from pyspark.sql import functions as F

# Define a struct for each employment
employment_struct = F.struct(
    "company_id", "company_name", "seniority_level", "title", "started_on", "ended_on"
)

# Group by person_id and collect list of employment details as structs
grouped_employments_df = person_employments_df.groupBy("person_id").agg(
    F.collect_list(employment_struct).alias("employments"),
    F.max("created_at").alias("latest_emp_created_at"),
    F.max("updated_at").alias("latest_emp_updated_at")
)

grouped_employments_df = grouped_employments_df.withColumnRenamed("person_id","person_id_emp")
# Show the result
grouped_employments_df.show(5,truncate=False)
# Out:
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |person_id_emp|employments                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |latest_emp_created_at     |latest_emp_updated_at|
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# |101255       |[{4207, Netscape, Manager, Calendar Server Development Manager, 1996-01-01, 1998-01-01}, {26, eBay, CXO, Chief Technology Officer Of Local Classifieds, 2007-09-01, 2011-06-01}, {77025, Yotta Technologies, NULL, Co-Founder, 2011-12-01, 2013-01-01}, {1660, Apple, NULL, Engineering Leader for Analytics and Data Products in Apple Media, 2016-10-01, NULL}, {1660, Apple, Head of ..., Head Of Foundation, Apple Online Store Engineering, 2015-08-01, 2016-10-01}, {20556, M/A-COM, NULL, Member Of Technical Staff, 1982-01-01, 1984-01-01}, {9307194, Onlive Technologies, NULL, Senior Software Developer, 1994-01-01, 1996-01-01}, {387, AOL, NULL, Senior Software Developer, 1998-01-01, 2001-01-01}, {10692885, Zip2save.Com, NULL, Senior Software Engineer, 1996-01-01, 1996-01-01}, {7854, Micro Focus, NULL, Senior Software Engineer, 1990-01-01, 1994-01-01}, {171553, GRiD Systems, NULL, Software Developer, 1984-01-01, 1990-01-01}, {26, eBay, NULL, Staff Software Engineer, 2001-04-01, 2001-12-01}, {26, eBay, Director, Technology Director, 2002-01-01, 2007-08-01}, {13385, FirstRain, VP, Vice President Of Engineering Operations, 2013-01-01, 2015-07-01}]                                                                                                                                                                                                                                                              |2023-12-11 06:18:49.396966|NULL                 |
# |124469       |[{7494192, Datagraph, CXO, CEO, 2018-01-01, 2018-12-01}, {4360, NVIDIA, NULL, Principal Applied Scientist, 2022-08-01, NULL}, {94027, 3Sourcing, CXO, Co-Founder & CTO, 2012-02-01, 2014-01-01}, {742393, RoboSelf, CXO, Founder & CEO, 2019-01-01, 2022-08-01}, {NULL, NULL, NULL, Co-Founder, 2008-09-01, 2012-01-01}, {389048, Wholi, CXO, Co-founder & CTO, 2014-01-01, 2018-01-01}, {188933, Kleenk, NULL, Founder, 2011-03-01, 2012-05-01}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |2023-12-11 06:18:49.396966|NULL                 |
# |149312       |[{29434, WiserTogether, Director, Director, Product Technology, 2011-10-01, 2013-08-01}, {11663, PBS, NULL, Sr. Manager, Education Technology Strategy, 2010-04-01, 2011-10-01}, {10395958, University At Buffalo, NULL, Adjunct Instructor, 2002-01-01, 2006-01-01}, {11737794, Univresity of Idaho, NULL, Temporary Lecturer, 2001-01-01, 2002-01-01}, {11737794, Univresity of Idaho, NULL, Teaching Assistant, 1999-09-01, 2001-05-01}, {NULL, NULL, NULL, Owner, 2001-01-01, 2007-05-01}, {4360, NVIDIA, NULL, Application Engineering Manager, Cloud Native Engineering, 2021-01-01, NULL}, {1749, NetApp, NULL, Sr. Engineering Manager, 2020-08-01, 2021-01-01}, {1749, NetApp, NULL, Sr. Engineering Manager, 2018-10-01, 2020-08-01}, {NULL, NULL, NULL, Freelance Technologist, 2013-08-01, 2020-12-01}, {116163, Seattle University, Director, Director of Web, Application and Technology Studies, 2014-03-01, 2018-09-01}, {314847, Speak Agent, Inc., NULL, Senior Application Developer, 2013-06-01, 2015-12-01}, {11663, PBS, NULL, Manager, Technology Solutions, 2008-02-01, 2010-04-01}, {11663, PBS, NULL, Web Technologist, 2006-08-01, 2008-02-01}]                                                                                                                                                                                                                                                                               |2023-12-11 06:18:49.396966|NULL                 |
# |175688       |[{NULL, NULL, CXO, Chief Product Officer, 2019-07-01, 2021-04-01}, {1401264, Reshuffle, CXO, Chief Product Officer, 2019-07-01, NULL}, {145383, Coridan, NULL, Core Architect, 2005-08-01, 2006-08-01}, {198960, Google, Manager, Developer Relations, Global Program Manager, 2014-01-01, 2015-08-01}, {198960, Google, Manager, Developer Relations Program Manager, 2011-06-01, 2014-01-01}, {10251277, Slack, Director, Director Of Developer Relations, 2015-11-01, 2018-02-01}, {NULL, NULL, NULL, Founder, 2006-01-01, 2006-12-01}, {NULL, NULL, NULL, Maintainer, 2000-01-01, 2010-01-01}, {13, Twitter, Manager, Production Manager, 2021-04-01, NULL}, {318671, Datacom, NULL, Senior Architect And Consultant, 2008-12-01, 2010-08-01}, {201690, Microsoft, NULL, Software Architecture Advisor, 2006-12-01, 2010-02-01}, {376076, iPace, NULL, Software Developer, 1999-04-01, 2000-08-01}, {21369, Mavenir, NULL, Software Developer, 2000-08-01, 2002-09-01}, {198960, Google, NULL, Startup Ecosystem Development Lead, Google Play, 2015-08-01, 2015-11-01}, {145383, Coridan, NULL, Team Leader, 2003-12-01, 2005-08-01}, {21369, Mavenir, NULL, Team Leader, 2002-10-01, 2003-12-01}, {41491, Innovation Endeavors, NULL, Venture Partner, 2021-05-01, 2021-05-01}, {88964, Twitch, VP, Vice President Of Product, Developer Experience, 2018-02-01, 2019-07-01}, {201690, Microsoft, NULL, Windows Azure Ssp, 2010-08-01, 2011-06-01}]|2023-12-11 06:18:49.396966|NULL                 |
# |225814       |[{2289, Netflix, NULL, Bilingual Product Writer, 2017-08-01, NULL}, {2289, Netflix, NULL, Bilingual Synopsis Writer, 2017-09-01, NULL}, {35129, The Hollywood Reporter, NULL, Contributing Editor, 2014-08-01, 2017-09-01}, {6507813, Abc Color, NULL, Features and News Reporter, 2011-12-01, 2012-04-01}, {117882, New York Post, NULL, Freelance Reporter, PageSix.com, 2007-12-01, 2008-03-01}, {259717, OK! Magazine, NULL, News Reporter, 2010-01-01, 2010-09-01}, {105, POPSUGAR, NULL, PopSugar NY Associate Editor, 2008-04-01, 2009-10-01}, {NULL, NULL, NULL, Reporter/Photojournalist, 2014-08-01, NULL}, {171735, Clarin, NULL, Reporting Fellow, 2013-06-01, 2013-08-01}, {8200938, HollywoodLife, NULL, Senior Editor, West Coast, 2010-12-01, 2011-10-01}, {122968, Steve & Barry's, Director, Special Projects Director, Celebrity Services, 2006-07-01, 2008-04-01}, {167504, OZY Media, NULL, Writer/Editor, 2013-08-01, 2014-08-01}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |2023-12-11 06:18:49.396966|NULL                 |
# +-------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+---------------------+
# only showing top 5 rows

# %%
# Join person_customer_education_joined_df and grouped_employments_df based on person_id
final_df = person_customer_education_joined_df.join(
    grouped_employments_df,
    person_customer_education_joined_df.person_id_pc == grouped_employments_df.person_id_emp,
    "inner"
).drop(grouped_employments_df.person_id_emp)

# Show the result
final_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|           name|address_ppl|   city|  region|postal_code|  country|    company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|           institute|latest_edu_created_at|latest_edu_updated_at|         employments|latest_emp_created_at|latest_emp_updated_at|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|    Vivian Weng|       NULL|   NULL|    NULL|       NULL|SINGAPORE|        DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|[{15861, DBS Bank...| 2023-12-11 06:18:...|                 NULL|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849|Courtney Turner|       NULL| Toledo|    Ohio|       NULL|       US|           Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, The Unive...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, NU...| 2023-12-11 06:18:...|                 NULL|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|  Katie Richter|       NULL| Austin|   Texas|       NULL|       US|Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Rhodes Co...| 2023-12-11 06:18:...|                 NULL|[{601281, Casting...| 2023-12-11 06:18:...|                 NULL|
# |     1373896|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   40|2024-02-07 11:24:...|      1373896|Chelsea Kanduth|       NULL|Chicago|Illinois|       NULL|       US|     Red Lobster|           NULL|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|2014-05-01|2015-12-01|    429133|2023-12-11 06:18:...|2023-10-26 15:57:...|[{6356260, St. Cl...| 2023-12-11 06:18:...|                 NULL|[{429133, Red Lob...| 2023-12-11 06:18:...|                 NULL|
# |    51432999|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  105|2024-02-09 12:08:...|     51432999|   Juan Sanchez|       NULL|  Boise|   Idaho|       NULL|       US|           Apple|       Director|Art Director at A...|        Art Director|                NULL|      NULL|      NULL|      1660|2023-12-11 06:18:...|2023-10-18 23:07:...|[{NULL, Minico Hi...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, Di...| 2023-12-11 06:18:...|                 NULL|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# only showing top 5 rows

# %%
person_social_urls_df = load_table("person_social_urls")
person_social_urls_df.show(5)
# Out:
# +-----+---------+--------------------+--------+--------------------+----------+
# |   id|person_id|                 url|url_type|          created_at|updated_at|
# +-----+---------+--------------------+--------+--------------------+----------+
# |12791|693540132|https://www.linke...|linkedin|2023-12-11 06:18:...|      NULL|
# |12792|118418234|https://www.linke...|linkedin|2023-12-11 06:18:...|      NULL|
# |12793|118418234|facebook.com/kenn...|facebook|2023-12-11 06:18:...|      NULL|
# |12794| 64876372|https://www.linke...|linkedin|2023-12-11 06:18:...|      NULL|
# |12795| 64876372|facebook.com/docl...|facebook|2023-12-11 06:18:...|      NULL|
# +-----+---------+--------------------+--------+--------------------+----------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

# Group by person_id and collect list of URL details
grouped_urls_df = person_social_urls_df.groupBy("person_id").agg(
    F.collect_list(
        F.struct("url_type", "url")
    ).alias("urls"),
    F.max("created_at").alias("latest_url_created_at"),
    F.max("updated_at").alias("latest_url_updated_at")
)

# Show the result

grouped_urls_df = grouped_urls_df.withColumnRenamed("person_id","person_id_url")
grouped_urls_df.show(5,truncate=False)
# Out:
# +-------------+------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+---------------------+
# |person_id_url|urls                                                                                                                                      |latest_url_created_at    |latest_url_updated_at|
# +-------------+------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+---------------------+
# |101255       |[{linkedin, https://www.linkedin.com/in/richardshusterman}, {crunchbase, https://crunchbase.com/person/richard-shusterman}]               |2023-12-11 06:18:57.46109|NULL                 |
# |124469       |[{linkedin, https://www.linkedin.com/in/drazvan}, {crunchbase, https://crunchbase.com/person/razvan-dinu}]                                |2023-12-11 06:18:57.46109|NULL                 |
# |149312       |[{linkedin, https://www.linkedin.com/in/shawnrider}, {crunchbase, https://crunchbase.com/person/shawn-rider}, {github, github.com/shawnr}]|2023-12-11 06:18:57.46109|NULL                 |
# |175688       |[{linkedin, https://www.linkedin.com/in/amirshevat}, {crunchbase, https://crunchbase.com/person/amir-shevat}]                             |2023-12-11 06:18:57.46109|NULL                 |
# |225814       |[{linkedin, https://www.linkedin.com/in/lorena-o-neil-20973857}, {crunchbase, https://crunchbase.com/person/lorena-oneil}]                |2023-12-11 06:18:57.46109|NULL                 |
# +-------------+------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+---------------------+
# only showing top 5 rows

# %%
#grouped_urls_df = grouped_urls_df.drop("urls")
#grouped_urls_df.show(5,truncate=False)

# %%
# Join final_df and grouped_urls_df based on person_id
result_df = final_df.join(
    grouped_urls_df,
    final_df.person_id_pc == grouped_urls_df.person_id_url,
    "inner"
).drop(grouped_urls_df.person_id_url)

# Show the result
result_df.show(5)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|           name|address_ppl|   city|  region|postal_code|  country|    company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|           institute|latest_edu_created_at|latest_edu_updated_at|         employments|latest_emp_created_at|latest_emp_updated_at|                urls|latest_url_created_at|latest_url_updated_at|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|    Vivian Weng|       NULL|   NULL|    NULL|       NULL|SINGAPORE|        DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|[{15861, DBS Bank...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849|Courtney Turner|       NULL| Toledo|    Ohio|       NULL|       US|           Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, The Unive...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, NU...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|  Katie Richter|       NULL| Austin|   Texas|       NULL|       US|Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Rhodes Co...| 2023-12-11 06:18:...|                 NULL|[{601281, Casting...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |     1373896|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   40|2024-02-07 11:24:...|      1373896|Chelsea Kanduth|       NULL|Chicago|Illinois|       NULL|       US|     Red Lobster|           NULL|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|2014-05-01|2015-12-01|    429133|2023-12-11 06:18:...|2023-10-26 15:57:...|[{6356260, St. Cl...| 2023-12-11 06:18:...|                 NULL|[{429133, Red Lob...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    51432999|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  105|2024-02-09 12:08:...|     51432999|   Juan Sanchez|       NULL|  Boise|   Idaho|       NULL|       US|           Apple|       Director|Art Director at A...|        Art Director|                NULL|      NULL|      NULL|      1660|2023-12-11 06:18:...|2023-10-18 23:07:...|[{NULL, Minico Hi...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, Di...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# only showing top 5 rows

# %%
# Count the distinct occurrences of person_id
distinct_count = result_df.select("person_id_pc").distinct().count()

# Count the total number of rows in the DataFrame
total_rows = result_df.count()

# Check if the DataFrame is unique based on person_id
if distinct_count == total_rows:
    print("DataFrame is unique based on person_id")
else:
    print("DataFrame is not unique based on person_id")
# Out:
# DataFrame is unique based on person_id

# %%
# Define the columns to show
columns_to_show = ["person_id_pc", "name", "description", "title", "headline", "city", "region", "postal_code", "country","employments", "institute","urls"]

# Select the specified columns and show the result
result_df.select(columns_to_show).show(5)
# Out:
# +------------+---------------+--------------------+--------------------+--------------------+-------+--------+-----------+---------+--------------------+--------------------+--------------------+
# |person_id_pc|           name|         description|               title|            headline|   city|  region|postal_code|  country|         employments|           institute|                urls|
# +------------+---------------+--------------------+--------------------+--------------------+-------+--------+-----------+---------+--------------------+--------------------+--------------------+
# |   949256266|    Vivian Weng|                NULL|Vice President, I...|Product Design, S...|   NULL|    NULL|       NULL|SINGAPORE|[{15861, DBS Bank...|[{NULL, Universit...|[{linkedin, https...|
# |    48171849|Courtney Turner|The search for so...|    Creative Trainer|                NULL| Toledo|    Ohio|       NULL|       US|[{1660, Apple, NU...|[{NULL, The Unive...|[{linkedin, https...|
# |    74707094|  Katie Richter|Retail Business S...|BUSINESS DEVELOPMENT|                NULL| Austin|   Texas|       NULL|       US|[{601281, Casting...|[{NULL, Rhodes Co...|[{linkedin, https...|
# |     1373896|Chelsea Kanduth|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|Chicago|Illinois|       NULL|       US|[{429133, Red Lob...|[{6356260, St. Cl...|[{linkedin, https...|
# |    51432999|   Juan Sanchez|Art Director at A...|        Art Director|                NULL|  Boise|   Idaho|       NULL|       US|[{1660, Apple, Di...|[{NULL, Minico Hi...|[{linkedin, https...|
# +------------+---------------+--------------------+--------------------+--------------------+-------+--------+-----------+---------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
# Select the specified columns and show the first row
result_df.select(columns_to_show).first()
# Out:
# Row(person_id_pc=949256266, name='Vivian Weng', description=None, title='Vice President, Innovation Group', headline='Product Design, Strategy & Managment', city=None, region=None, postal_code=None, country='SINGAPORE', employments=[Row(company_id=15861, company_name='DBS Bank', seniority_level='VP', title='Vice President, Innovation Group', started_on=datetime.date(2016, 7, 1), ended_on=datetime.date(2019, 4, 1)), Row(company_id=7962172, company_name='Frog', seniority_level='Director', title='Associate Strategy Director, Innovation Strategy Group', started_on=datetime.date(2012, 2, 1), ended_on=datetime.date(2016, 6, 1)), Row(company_id=4007, company_name='McKinsey & Company', seniority_level=None, title='Business Analyst', started_on=datetime.date(2004, 1, 1), ended_on=datetime.date(2007, 1, 1)), Row(company_id=4007, company_name='McKinsey & Company', seniority_level=None, title='Senior Associate, Corporate Finance', started_on=datetime.date(2009, 9, 1), ended_on=datetime.date(2011, 11, 1)), Row(company_id=59, company_name='Goldman Sachs', seniority_level=None, title='Investment Banking Division Summer Associate', started_on=datetime.date(2008, 6, 1), ended_on=datetime.date(2008, 8, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Product Design Producer, International Product Design', started_on=datetime.date(2019, 4, 1), ended_on=None)], institute=[Row(institution_id=None, institution_name='University of California, Berkeley - Walter A. Haas School of Business', degree=None, subject='MBA, Finance', started_on=datetime.date(2007, 1, 1), ended_on=datetime.date(2009, 1, 1)), Row(institution_id=None, institution_name='National Taiwan University', degree=None, subject='BA, International Relations', started_on=datetime.date(1998, 1, 1), ended_on=datetime.date(2002, 1, 1)), Row(institution_id=None, institution_name='Yale University', degree=None, subject='MA, International Developmental Economics', started_on=datetime.date(2002, 1, 1), ended_on=datetime.date(2003, 1, 1))], urls=[Row(url_type='linkedin', url='https://www.linkedin.com/in/vivian-weng-4a0b884')])

# %%
result_df.show(5)
# paruest_ds = result_df.write.parquet("output.parquet")
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|           name|address_ppl|   city|  region|postal_code|  country|    company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|           institute|latest_edu_created_at|latest_edu_updated_at|         employments|latest_emp_created_at|latest_emp_updated_at|                urls|latest_url_created_at|latest_url_updated_at|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|    Vivian Weng|       NULL|   NULL|    NULL|       NULL|SINGAPORE|        DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|[{15861, DBS Bank...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849|Courtney Turner|       NULL| Toledo|    Ohio|       NULL|       US|           Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, The Unive...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, NU...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|  Katie Richter|       NULL| Austin|   Texas|       NULL|       US|Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Rhodes Co...| 2023-12-11 06:18:...|                 NULL|[{601281, Casting...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |     1373896|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   40|2024-02-07 11:24:...|      1373896|Chelsea Kanduth|       NULL|Chicago|Illinois|       NULL|       US|     Red Lobster|           NULL|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|2014-05-01|2015-12-01|    429133|2023-12-11 06:18:...|2023-10-26 15:57:...|[{6356260, St. Cl...| 2023-12-11 06:18:...|                 NULL|[{429133, Red Lob...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    51432999|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  105|2024-02-09 12:08:...|     51432999|   Juan Sanchez|       NULL|  Boise|   Idaho|       NULL|       US|           Apple|       Director|Art Director at A...|        Art Director|                NULL|      NULL|      NULL|      1660|2023-12-11 06:18:...|2023-10-18 23:07:...|[{NULL, Minico Hi...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, Di...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# +------------+--------------------+--------------------+-----+--------------------+-------------+---------------+-----------+-------+--------+-----------+---------+----------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# only showing top 5 rows

# %%
rows = result_df.select(columns_to_show).collect()

# Loop through each row and perform some operation
for row in rows:
    # Your operation goes here
    # For example, let's print each row as a string
    print(row.asDict())
# Out:
# {'person_id_pc': 949256266, 'name': 'Vivian Weng', 'description': None, 'title': 'Vice President, Innovation Group', 'headline': 'Product Design, Strategy & Managment', 'city': None, 'region': None, 'postal_code': None, 'country': 'SINGAPORE', 'employments': [Row(company_id=15861, company_name='DBS Bank', seniority_level='VP', title='Vice President, Innovation Group', started_on=datetime.date(2016, 7, 1), ended_on=datetime.date(2019, 4, 1)), Row(company_id=7962172, company_name='Frog', seniority_level='Director', title='Associate Strategy Director, Innovation Strategy Group', started_on=datetime.date(2012, 2, 1), ended_on=datetime.date(2016, 6, 1)), Row(company_id=4007, company_name='McKinsey & Company', seniority_level=None, title='Business Analyst', started_on=datetime.date(2004, 1, 1), ended_on=datetime.date(2007, 1, 1)), Row(company_id=4007, company_name='McKinsey & Company', seniority_level=None, title='Senior Associate, Corporate Finance', started_on=datetime.date(2009, 9, 1), ended_on=datetime.date(2011, 11, 1)), Row(company_id=59, company_name='Goldman Sachs', seniority_level=None, title='Investment Banking Division Summer Associate', started_on=datetime.date(2008, 6, 1), ended_on=datetime.date(2008, 8, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Product Design Producer, International Product Design', started_on=datetime.date(2019, 4, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='University of California, Berkeley - Walter A. Haas School of Business', degree=None, subject='MBA, Finance', started_on=datetime.date(2007, 1, 1), ended_on=datetime.date(2009, 1, 1)), Row(institution_id=None, institution_name='National Taiwan University', degree=None, subject='BA, International Relations', started_on=datetime.date(1998, 1, 1), ended_on=datetime.date(2002, 1, 1)), Row(institution_id=None, institution_name='Yale University', degree=None, subject='MA, International Developmental Economics', started_on=datetime.date(2002, 1, 1), ended_on=datetime.date(2003, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/vivian-weng-4a0b884')]}
# {'person_id_pc': 48171849, 'name': 'Courtney Turner', 'description': 'The search for something profound usually begins on a quest of "self."', 'title': 'Creative Trainer', 'headline': None, 'city': 'Toledo', 'region': 'Ohio', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1660, company_name='Apple', seniority_level=None, title='Creative Trainer', started_on=datetime.date(2018, 3, 1), ended_on=None), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Product Specialist', started_on=datetime.date(2016, 11, 1), ended_on=None), Row(company_id=6916840, company_name='Boys & Girls Clubs Of America', seniority_level='Director', title='Program Director', started_on=datetime.date(2013, 12, 1), ended_on=datetime.date(2016, 11, 1))], 'institute': [Row(institution_id=None, institution_name='The University Of Akron', degree=None, subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/courtney-turner-11949310a')]}
# {'person_id_pc': 74707094, 'name': 'Katie Richter', 'description': 'Retail Business Specialist, Assistant Supervisor', 'title': 'BUSINESS DEVELOPMENT', 'headline': None, 'city': 'Austin', 'region': 'Texas', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=601281, company_name='Casting Networks', seniority_level=None, title='BUSINESS DEVELOPMENT', started_on=datetime.date(2010, 5, 1), ended_on=datetime.date(2011, 4, 1)), Row(company_id=704079, company_name='Freelance', seniority_level='Director', title='CASTING DIRECTOR, CASTING ASSOCIATE', started_on=datetime.date(2011, 4, 1), ended_on=datetime.date(2012, 9, 1)), Row(company_id=6517068, company_name='Action Figure', seniority_level='Manager', title='OFFICE MANAGER, CLIENT SERVICE MANAGER', started_on=datetime.date(2008, 9, 1), ended_on=datetime.date(2010, 1, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Recruiting Coordinator', started_on=datetime.date(2016, 11, 1), ended_on=None), Row(company_id=1660, company_name='Apple', seniority_level=None, title='RETAIL SALES SUPPORT SPECIALIST, TEAM DEPUTY', started_on=datetime.date(2012, 9, 1), ended_on=None), Row(company_id=8035333, company_name='Geddes Agency', seniority_level='Manager', title='TALENT AGENT, OFFICE MANAGER', started_on=datetime.date(2005, 6, 1), ended_on=datetime.date(2008, 7, 1))], 'institute': [Row(institution_id=None, institution_name='Rhodes College', degree='Bachelors;Bachelor Of Science', subject='Theater;Theatre', started_on=datetime.date(2000, 1, 1), ended_on=datetime.date(2004, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/katie-richter-324083107')]}
# {'person_id_pc': 1373896, 'name': 'Chelsea Kanduth', 'description': 'Experienced Account Coordinator with a demonstrated history of working in the marketing and advertising industry, focusing on providing clients with technology that best suits their needs. A creative thinker, proficient problem solver and strong communicator with a Bachelor of Science (B.S.) in Marketing from St. Cloud State University - Herberger Business School.', 'title': 'Front-Line Sales, Waitress', 'headline': 'Advertising Guru - Multi-Channel Sales Planner at Chicago Tribune', 'city': 'Chicago', 'region': 'Illinois', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=429133, company_name='Red Lobster', seniority_level=None, title='Front-Line Sales, Waitress', started_on=datetime.date(2014, 5, 1), ended_on=datetime.date(2015, 12, 1)), Row(company_id=127189, company_name='ASPIRE Beverages', seniority_level=None, title='Market Representative', started_on=datetime.date(2014, 9, 1), ended_on=datetime.date(2015, 5, 1)), Row(company_id=7440868, company_name='American Marketing Association', seniority_level='VP', title='Vice President of Community Service', started_on=datetime.date(2014, 5, 1), ended_on=datetime.date(2014, 10, 1)), Row(company_id=121581, company_name='Chicago Tribune', seniority_level=None, title='Account Manager', started_on=datetime.date(2019, 7, 1), ended_on=datetime.date(2021, 8, 1)), Row(company_id=221821, company_name='Goose Island Beer Company', seniority_level=None, title='Marketing Content Specialist & Receptionist (Contractor)', started_on=datetime.date(2018, 10, 1), ended_on=datetime.date(2019, 5, 1)), Row(company_id=40487, company_name='MindShare', seniority_level=None, title='Receptionist (Contractor)', started_on=datetime.date(2018, 9, 1), ended_on=datetime.date(2018, 10, 1)), Row(company_id=14755, company_name='Agenda-Asia', seniority_level=None, title='Video Project Assistant (Contractor)', started_on=datetime.date(2018, 8, 1), ended_on=datetime.date(2018, 10, 1)), Row(company_id=71354, company_name='Enterprise Rent-A-Car', seniority_level=None, title='Sales & Management Intern', started_on=datetime.date(2016, 8, 1), ended_on=datetime.date(2016, 12, 1)), Row(company_id=1588268, company_name='National Office Furniture', seniority_level=None, title='Showroom Manager/Receptionist (Contractor)', started_on=datetime.date(2018, 9, 1), ended_on=datetime.date(2018, 9, 1)), Row(company_id=6916840, company_name='Boys & Girls Clubs Of America', seniority_level=None, title='Youth Guidance Worker (Summer Position)', started_on=datetime.date(2014, 5, 1), ended_on=datetime.date(2014, 8, 1)), Row(company_id=4053, company_name='Spotify', seniority_level=None, title='Account Manager', started_on=datetime.date(2021, 8, 1), ended_on=None), Row(company_id=45142, company_name='GroundTruth', seniority_level=None, title='Account Coordinator', started_on=datetime.date(2018, 11, 1), ended_on=datetime.date(2019, 1, 1))], 'institute': [Row(institution_id=6356260, institution_name='St. Cloud State University - Herberger Business School', degree='Bachelor of Science (B.S.)', subject='Marketing', started_on=datetime.date(2012, 1, 1), ended_on=datetime.date(2017, 1, 1)), Row(institution_id=None, institution_name='Griffith College (AUS)', degree='Bachelor of Science (BS)', subject='Marketing', started_on=datetime.date(2016, 1, 1), ended_on=datetime.date(2016, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/chelseakanduth')]}
# {'person_id_pc': 51432999, 'name': 'Juan Sanchez', 'description': 'Art Director at Apple', 'title': 'Art Director', 'headline': None, 'city': 'Boise', 'region': 'Idaho', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1660, company_name='Apple', seniority_level='Director', title='Art Director', started_on=None, ended_on=None)], 'institute': [Row(institution_id=None, institution_name='Minico High School', degree=None, subject=None, started_on=datetime.date(2011, 1, 1), ended_on=datetime.date(2014, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/juan-sanchez-884997117')]}
# {'person_id_pc': 1420981, 'name': 'Jasmine Scofield', 'description': '6+ years in End-To-End payroll processing. Multi State/Local tax authorities. SOX compliant. Strategic business partner / payroll project management. Proficient in managing ESPP Purchases, 401k Year End Audits, Visa processes, payroll accounting', 'title': 'Administrative Assistant', 'headline': 'Senior Payroll Analyst at Netflix', 'city': 'Santa Clara', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1524224, company_name='DHL Supply Chain', seniority_level=None, title='Administrative Assistant', started_on=datetime.date(2015, 8, 1), ended_on=datetime.date(2016, 10, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Payroll Administrator', started_on=datetime.date(2015, 5, 1), ended_on=datetime.date(2015, 8, 1)), Row(company_id=2289, company_name='Netflix', seniority_level=None, title='Senior Payroll Analyst', started_on=datetime.date(2020, 10, 1), ended_on=None), Row(company_id=7942432, company_name='Forte Vision Marketing Inc.', seniority_level=None, title='Administrative Assistant', started_on=datetime.date(2015, 2, 1), ended_on=datetime.date(2015, 5, 1)), Row(company_id=1370911, company_name='Facebook', seniority_level=None, title='Payroll Specialist', started_on=datetime.date(2017, 1, 1), ended_on=datetime.date(2017, 9, 1)), Row(company_id=47401, company_name='Pure Storage', seniority_level=None, title='Senior Payroll Analyst', started_on=datetime.date(2020, 3, 1), ended_on=datetime.date(2020, 10, 1)), Row(company_id=47401, company_name='Pure Storage', seniority_level=None, title='Payroll Analyst', started_on=datetime.date(2019, 6, 1), ended_on=datetime.date(2020, 10, 1)), Row(company_id=None, company_name=None, seniority_level='CXO', title='CFO', started_on=datetime.date(2013, 1, 1), ended_on=datetime.date(2015, 1, 1)), Row(company_id=6772692, company_name='ATT InoxDrain', seniority_level=None, title='Data Entry Assistant', started_on=datetime.date(2013, 7, 1), ended_on=datetime.date(2014, 5, 1)), Row(company_id=40278, company_name='Quotient Technology', seniority_level=None, title='Payroll Analyst', started_on=datetime.date(2017, 11, 1), ended_on=datetime.date(2018, 7, 1)), Row(company_id=139, company_name='Yelp', seniority_level=None, title='Payroll Processor', started_on=datetime.date(2017, 1, 1), ended_on=datetime.date(2017, 1, 1)), Row(company_id=10443525, company_name='Valley Relocation & Storage', seniority_level=None, title='Payroll Clerk', started_on=datetime.date(2012, 6, 1), ended_on=datetime.date(2012, 10, 1)), Row(company_id=910, company_name='Electronic Arts', seniority_level=None, title='Senior Payroll Analyst', started_on=datetime.date(2018, 7, 1), ended_on=datetime.date(2019, 6, 1))], 'institute': [Row(institution_id=193734, institution_name='Diablo Valley College', degree='Business Administration and Management, General', subject=None, started_on=None, ended_on=None), Row(institution_id=195568, institution_name='Evergreen Valley College', degree='Small Business Administration/Management', subject=None, started_on=None, ended_on=None), Row(institution_id=195568, institution_name='Evergreen Valley College', degree='Business Administration and Management, General', subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/jasmine-scofield-85049ab6')]}
# {'person_id_pc': 22565708, 'name': 'Tim Wong', 'description': 'Execution fanatic empowered by driving and developing organizations and facilitating its tight synchronization via communication.  Consistently able to deliver business and technical results with extensive planning including risk assessments, while keeping up a rapid rate of positive progress.', 'title': 'Chief Marketing Officer', 'headline': 'Technical Marketing for Autonomous Vehicles, NVIDIA', 'city': 'Danville', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1334078, company_name='HFTrading', seniority_level='CXO', title='Chief Marketing Officer', started_on=datetime.date(2013, 12, 1), ended_on=datetime.date(2014, 7, 1)), Row(company_id=None, company_name=None, seniority_level='CXO', title='Founder & CTO', started_on=datetime.date(1999, 1, 1), ended_on=datetime.date(2001, 3, 1)), Row(company_id=905, company_name='Nokia', seniority_level='Director', title='IT Director', started_on=datetime.date(1996, 9, 1), ended_on=datetime.date(1999, 10, 1)), Row(company_id=6772692, company_name='ATT InoxDrain', seniority_level='Director', title='Deputy Director', started_on=datetime.date(1986, 7, 1), ended_on=datetime.date(1997, 1, 1)), Row(company_id=4360, company_name='NVIDIA', seniority_level=None, title='Technical Marketing for Automotive Vehicles', started_on=datetime.date(2014, 12, 1), ended_on=None), Row(company_id=11738, company_name='Silicon Image', seniority_level=None, title='Partnerships and Business Development', started_on=datetime.date(2014, 10, 1), ended_on=datetime.date(2014, 12, 1)), Row(company_id=11738, company_name='Silicon Image', seniority_level='CXO', title='President MHL Consortium & Chairman WiHD Consortium', started_on=datetime.date(2010, 11, 1), ended_on=datetime.date(2013, 12, 1)), Row(company_id=349, company_name='Qualcomm', seniority_level='Director', title='Director, Program Management', started_on=datetime.date(2004, 11, 1), ended_on=datetime.date(2010, 11, 1)), Row(company_id=13305, company_name='Ubicom', seniority_level='Director', title='Director of Customer Engineering', started_on=datetime.date(2001, 4, 1), ended_on=datetime.date(2004, 11, 1)), Row(company_id=334319, company_name='Draper', seniority_level=None, title='Staff Engineer', started_on=datetime.date(1984, 1, 1), ended_on=datetime.date(1986, 1, 1)), Row(company_id=6806364, company_name='Autonomous Vehicle Computing Consortium', seniority_level=None, title='Chair, Marketing Committee', started_on=datetime.date(2019, 6, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='At&T School Of Business / Wharton School At Upenn', degree='Master Of Business Administration;Masters', subject='Finance', started_on=datetime.date(1995, 1, 1), ended_on=datetime.date(1995, 1, 1)), Row(institution_id=None, institution_name='University Of Southern California', degree='Master Of Science;Masters', subject='Computer Science', started_on=datetime.date(1987, 9, 1), ended_on=datetime.date(1988, 1, 1)), Row(institution_id=None, institution_name='Boston University', degree='Bachelors;Bachelor Of Science', subject='Computer Engineering', started_on=datetime.date(1982, 9, 1), ended_on=datetime.date(1986, 1, 1)), Row(institution_id=None, institution_name='Punahou School', degree=None, subject=None, started_on=datetime.date(1972, 1, 1), ended_on=datetime.date(1982, 1, 1)), Row(institution_id=None, institution_name='Lucent / Stevens Inst. Of Tech', degree=None, subject='Management', started_on=datetime.date(1997, 1, 1), ended_on=datetime.date(1997, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/timwong'), Row(url_type='facebook', url='facebook.com/timwong314'), Row(url_type='twitter', url='twitter.com/wongtim')]}
# {'person_id_pc': 71726687, 'name': 'Katherine Hicks', 'description': 'Results Driven, Creative Leader with Exceptional People Skills', 'title': 'Art Director', 'headline': None, 'city': 'Bay Village', 'region': 'Ohio', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=145458, company_name='Girl Scouts of North East Ohio', seniority_level='Director', title='Art Director', started_on=datetime.date(2007, 6, 1), ended_on=datetime.date(2010, 8, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='At-Home Advisor', started_on=datetime.date(2015, 8, 1), ended_on=None), Row(company_id=201768, company_name='Lessons.com', seniority_level=None, title='Piano Instructor', started_on=datetime.date(2007, 9, 1), ended_on=None), Row(company_id=108182, company_name="Macy's", seniority_level=None, title='Salesperson', started_on=datetime.date(2011, 6, 1), ended_on=datetime.date(2012, 9, 1)), Row(company_id=108182, company_name="Macy's", seniority_level=None, title='Sales Supervisor', started_on=datetime.date(2013, 5, 1), ended_on=datetime.date(2014, 10, 1)), Row(company_id=108182, company_name="Macy's", seniority_level=None, title='Star Selling Ambassador', started_on=datetime.date(2012, 9, 1), ended_on=datetime.date(2013, 4, 1)), Row(company_id=194364, company_name='Barnard College', seniority_level=None, title='Web Designer', started_on=datetime.date(2007, 9, 1), ended_on=datetime.date(2009, 5, 1))], 'institute': [Row(institution_id=None, institution_name='Barnard College', degree='Bachelors', subject='Music', started_on=datetime.date(2006, 1, 1), ended_on=datetime.date(2010, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/katherine-hicks-437046101')]}
# {'person_id_pc': 20891932, 'name': 'Cynthia Collins', 'description': '18 years of progressive experience in Human Resources, Organizational Development, Program and People Management. Proven success in delivering high quality results in alignment with business strategies, client objectives and company culture.', 'title': 'Customer Relations Specialist', 'headline': None, 'city': 'San Francisco', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1660, company_name='Apple', seniority_level=None, title='Customer Relations Specialist', started_on=datetime.date(1985, 1, 1), ended_on=datetime.date(1986, 1, 1)), Row(company_id=1660, company_name='Apple', seniority_level='Manager', title='Customer Relations Manager', started_on=datetime.date(1989, 1, 1), ended_on=datetime.date(1991, 1, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Customer Relations Supervisor', started_on=datetime.date(1986, 1, 1), ended_on=datetime.date(1989, 1, 1)), Row(company_id=8295289, company_name='Hp Palm', seniority_level='Director', title='Human Resources Director', started_on=datetime.date(2007, 1, 1), ended_on=datetime.date(2012, 3, 1)), Row(company_id=9282, company_name='Silicon Graphics', seniority_level=None, title='Human Resources Specialist', started_on=datetime.date(1994, 1, 1), ended_on=datetime.date(1996, 1, 1)), Row(company_id=9282, company_name='Silicon Graphics', seniority_level=None, title='Human Resources Representative', started_on=datetime.date(1996, 1, 1), ended_on=datetime.date(1997, 1, 1)), Row(company_id=9282, company_name='Silicon Graphics', seniority_level='Manager', title='HR Manager - HR Shared Services', started_on=datetime.date(1997, 1, 1), ended_on=datetime.date(1999, 1, 1)), Row(company_id=11742, company_name='Xilinx', seniority_level=None, title='Senior HR Business Partner', started_on=datetime.date(1999, 1, 1), ended_on=datetime.date(2004, 1, 1)), Row(company_id=11742, company_name='Xilinx', seniority_level='Manager', title='Senior Manager, WW HR Global Learning', started_on=datetime.date(2004, 1, 1), ended_on=datetime.date(2007, 1, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Senior Human Resources Business Partner', started_on=datetime.date(2012, 2, 1), ended_on=None), Row(company_id=9282, company_name='Silicon Graphics', seniority_level=None, title='Staffing Specialist', started_on=datetime.date(1992, 1, 1), ended_on=datetime.date(1994, 1, 1))], 'institute': [Row(institution_id=None, institution_name='University Of Washington', degree=None, subject='Communications', started_on=None, ended_on=None), Row(institution_id=None, institution_name='San Jose State University', degree='Bachelors;Bachelor Of Arts', subject='Journalism', started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/cynthia-collins-9658853b')]}
# {'person_id_pc': 22355698, 'name': 'Ritchie Lozada', 'description': 'Passion for complex development projects.', 'title': 'Asst. General Manager / Network Administrator', 'headline': None, 'city': 'San Francisco', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=None, company_name=None, seniority_level='Manager', title='Asst. General Manager / Network Administrator', started_on=datetime.date(1994, 1, 1), ended_on=datetime.date(1996, 1, 1)), Row(company_id=192586, company_name='Ateneo de Manila University', seniority_level=None, title='Asst. Instructor, Computer Science', started_on=datetime.date(1993, 1, 1), ended_on=datetime.date(1996, 1, 1)), Row(company_id=None, company_name=None, seniority_level='Director', title='Managing Director, R&D Group', started_on=datetime.date(1996, 1, 1), ended_on=datetime.date(1999, 1, 1)), Row(company_id=8331204, company_name='Interactive Images Inc.', seniority_level=None, title='Managing Partner / Lead Developer', started_on=datetime.date(1996, 1, 1), ended_on=datetime.date(1998, 1, 1)), Row(company_id=201690, company_name='Microsoft', seniority_level=None, title='Principal Software Development Engineer, Dx-Ted And Commercial Software Engineering', started_on=datetime.date(1999, 11, 1), ended_on=datetime.date(2018, 1, 1)), Row(company_id=201690, company_name='Microsoft', seniority_level=None, title='Principal Consultant, Microsoft Consulting Services', started_on=datetime.date(1999, 1, 1), ended_on=datetime.date(2008, 1, 1)), Row(company_id=192586, company_name='Ateneo de Manila University', seniority_level=None, title='Researcher', started_on=datetime.date(1992, 1, 1), ended_on=datetime.date(1993, 1, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Software Engineer', started_on=datetime.date(2018, 1, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='Ateneo De Manila University', degree=None, subject='Computer Science', started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/ritchielozada'), Row(url_type='github', url='github.com/rlozada')]}
# {'person_id_pc': 734368, 'name': 'Abby Anderson Edling', 'description': 'Results-oriented marketing professional with over 16 years of marketing experience across brand management, online marketing, email marketing, and digital marketing. Passionate about personalized marketing experiences enabled through close partnerships with Product Management, Analytics, Merchandising, and Marketing. Recognized for an enthusiasm to enhance the customer experience by offering innovative solutions that deliver improved performance results.', 'title': 'Apple News Marketing Lead', 'headline': 'Marketing at Apple', 'city': 'San Francisco', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1660, company_name='Apple', seniority_level=None, title='Apple News Marketing Lead', started_on=datetime.date(2018, 3, 1), ended_on=datetime.date(2019, 7, 1)), Row(company_id=10456, company_name='Gap', seniority_level='Manager', title='Assistant Brand Manager, Gap Brand Management', started_on=datetime.date(2005, 2, 1), ended_on=datetime.date(2005, 4, 1)), Row(company_id=10456, company_name='Gap', seniority_level='Manager', title='Associate Marketing Manager, Site & Email Marketing - Gap Online', started_on=datetime.date(2005, 5, 1), ended_on=datetime.date(2007, 7, 1)), Row(company_id=10456, company_name='Gap', seniority_level='Director', title='Director Global Display Media, Gap Inc.', started_on=datetime.date(2015, 8, 1), ended_on=datetime.date(2016, 7, 1)), Row(company_id=565441, company_name='Texture by Next Issue', seniority_level='Director', title='Director Paid Marketing', started_on=datetime.date(2016, 7, 1), ended_on=datetime.date(2018, 3, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='Marketing', started_on=datetime.date(2018, 4, 1), ended_on=None), Row(company_id=10456, company_name='Gap', seniority_level='Manager', title='Marketing Manager, Site & Email Marketing - Gap Online', started_on=datetime.date(2007, 8, 1), ended_on=datetime.date(2010, 2, 1)), Row(company_id=10456, company_name='Gap', seniority_level=None, title='Sr. Coordinator, Gap Brand Management', started_on=datetime.date(2003, 2, 1), ended_on=datetime.date(2005, 1, 1)), Row(company_id=10456, company_name='Gap', seniority_level='Manager', title='Sr. Manager Global Display Media, Gap Inc.', started_on=datetime.date(2011, 5, 1), ended_on=datetime.date(2015, 7, 1)), Row(company_id=10456, company_name='Gap', seniority_level='Manager', title='Sr. Marketing Manager, Site & Email Marketing - Gap Online', started_on=datetime.date(2010, 2, 1), ended_on=datetime.date(2011, 3, 1)), Row(company_id=7101313, company_name='Cal Poly College Of Engineering', seniority_level=None, title='Web Designer / Computer Held Desk Technical Support Lead', started_on=datetime.date(1999, 11, 1), ended_on=datetime.date(2002, 6, 1))], 'institute': [Row(institution_id=194218, institution_name='Complutense University of Madrid', degree='Spanish Language Studies', subject='Cultural Experiences Abroad', started_on=datetime.date(2001, 1, 1), ended_on=datetime.date(2001, 1, 1)), Row(institution_id=196266, institution_name='California Polytechnic State University', degree='B.S.', subject='Business Administration, Management', started_on=datetime.date(1998, 1, 1), ended_on=datetime.date(2002, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/abby-anderson-edling-556b933'), Row(url_type='crunchbase', url='https://crunchbase.com/person/abby-anderson-edling')]}
# {'person_id_pc': 89239536, 'name': 'John Serpiello', 'description': 'Leader in the Service Industry. Developing workflows, key processes and service products that deliver a clear distinction in the market place. Leading teams to achieve unity and consistency in Service delivery. Creating culture of  accountability-execution-customer service. Lifetime of experience in serving customers through innovation and never resting on past success. Supporting the world’s best products with the world’s Greatest Service and Support. Infusing Excellence in Operations.', 'title': 'Vice President, Service Operations', 'headline': 'Vice President of Business Development and After Market Service at Cannon Equipment/ A Marmon-Berkshire Hathaway Company', 'city': 'Philadelphia', 'region': 'Pennsylvania', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=655474, company_name='Hobart Service', seniority_level='VP', title='Vice President, Service Operations', started_on=datetime.date(2016, 8, 1), ended_on=datetime.date(2017, 9, 1)), Row(company_id=655474, company_name='Hobart Service', seniority_level='Director', title='Director, Hobart Service Northeast Region', started_on=datetime.date(2010, 9, 1), ended_on=datetime.date(2016, 8, 1)), Row(company_id=655474, company_name='Hobart Service', seniority_level='Director', title='Director, Hobart Service Mid Atlantic Region', started_on=datetime.date(2008, 6, 1), ended_on=datetime.date(2010, 9, 1)), Row(company_id=655474, company_name='Hobart Service', seniority_level=None, title='Branch Manager', started_on=datetime.date(2004, 1, 1), ended_on=datetime.date(2008, 6, 1)), Row(company_id=None, company_name=None, seniority_level='VP', title='Vice President of Business Development and After Market Service', started_on=datetime.date(2019, 5, 1), ended_on=None), Row(company_id=None, company_name=None, seniority_level='VP', title='Vice President Global Service', started_on=datetime.date(2017, 9, 1), ended_on=datetime.date(2019, 5, 1)), Row(company_id=110721, company_name='Berkshire Hathaway', seniority_level='VP', title='Vice President of Business Development at Cannon Equipment, LA Darling, and Unarco', started_on=datetime.date(2022, 1, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='Pennco Technical Institute', degree='Associates', subject=None, started_on=datetime.date(1987, 1, 1), ended_on=datetime.date(1989, 1, 1)), Row(institution_id=None, institution_name='Holy Family University', degree='Master Of Business Administration;Masters', subject=None, started_on=datetime.date(2013, 1, 1), ended_on=None), Row(institution_id=None, institution_name='Holy Family University', degree='Master Of Business Administration;Masters', subject=None, started_on=datetime.date(2012, 1, 1), ended_on=datetime.date(2014, 1, 1)), Row(institution_id=None, institution_name='Holy Family University', degree='Bachelors', subject='Business Administration;Economics;Management;Business', started_on=datetime.date(2001, 1, 1), ended_on=datetime.date(2006, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/johnserpiello'), Row(url_type='twitter', url='twitter.com/serpiello')]}
# {'person_id_pc': 574392, 'name': 'Dushyant Sapre 杜勝', 'description': 'A well rounded digital business leader with expertise in managing JAPAC P&L, attracting top talent and building sustainable go-to-market strategy for Asia-Pacific expansion.\\nSuccessfully built multi million dollar SaaS based B2B businesses in mobile gaming, e-commerce & online media.\\nPassionate about working with people across cultures and committed to supporting inclusion and women in tech.\\nProud alum of IIT Delhi (Engineering) and INSEAD (MBA).', 'title': 'Area Sales Manager', 'headline': 'Managing Director MoPub@Twitter| Venture Partner@Antler| Champion for inclusion & diversity in Tech| INSEAD and IIT', 'city': None, 'region': None, 'postal_code': None, 'country': 'SG', 'employments': [Row(company_id=108622, company_name='Tata Motors', seniority_level='Manager', title='Area Sales Manager', started_on=datetime.date(2006, 7, 1), ended_on=datetime.date(2007, 6, 1)), Row(company_id=1903, company_name='Criteo', seniority_level='Board Member', title='Board Observer - Criteo K.K. (Joint venture between Yahoo Japan and Criteo)', started_on=datetime.date(2017, 1, 1), ended_on=datetime.date(2019, 9, 1)), Row(company_id=198960, company_name='Google', seniority_level=None, title='Business Development & Sales Leader - South Asia', started_on=datetime.date(2011, 1, 1), ended_on=datetime.date(2012, 8, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Charter Member', started_on=datetime.date(2019, 12, 1), ended_on=None), Row(company_id=1903, company_name='Criteo', seniority_level='Director', title='Director of Business Development - Australia, India & South East Asia', started_on=datetime.date(2013, 10, 1), ended_on=datetime.date(2016, 12, 1)), Row(company_id=1903, company_name='Criteo', seniority_level='Director', title='Founder & Global Managing Director - App Partnerships and Business Development', started_on=datetime.date(2018, 7, 1), ended_on=datetime.date(2019, 9, 1)), Row(company_id=1903, company_name='Criteo', seniority_level='Director', title='Interim Managing Director - India', started_on=datetime.date(2016, 9, 1), ended_on=datetime.date(2017, 6, 1)), Row(company_id=108622, company_name='Tata Motors', seniority_level=None, title='Internal Distribution Strategy Consultant', started_on=datetime.date(2005, 7, 1), ended_on=datetime.date(2006, 6, 1)), Row(company_id=13, company_name='Twitter', seniority_level='Director', title='Managing Director for Japan and Asia Pacific, Mopub', started_on=datetime.date(2019, 9, 1), ended_on=None), Row(company_id=204949, company_name='INSEAD', seniority_level=None, title='MBA Candidate', started_on=datetime.date(2012, 9, 1), ended_on=datetime.date(2013, 7, 1)), Row(company_id=779828, company_name='XA Network', seniority_level=None, title='Member & Angel Investor', started_on=datetime.date(2020, 2, 1), ended_on=None), Row(company_id=392, company_name='HP', seniority_level='Manager', title='Territory Manager - Personal Systems Group', started_on=datetime.date(2007, 6, 1), ended_on=datetime.date(2008, 10, 1)), Row(company_id=622559, company_name='Antler', seniority_level=None, title='Venture Partner', started_on=datetime.date(2018, 7, 1), ended_on=None), Row(company_id=392, company_name='HP', seniority_level='Manager', title='Zonal Business Manager- Emerging Businesses', started_on=datetime.date(2008, 10, 1), ended_on=datetime.date(2010, 10, 1))], 'institute': [Row(institution_id=196642, institution_name='Indian Institute of Technology, Delhi', degree='Bachelor of Technology (B.Tech.)', subject=None, started_on=None, ended_on=None), Row(institution_id=None, institution_name='Dartmouth College - The Tuck School of Business at Dartmouth', degree='Business Bridge Program', subject=None, started_on=None, ended_on=None), Row(institution_id=204949, institution_name='INSEAD', degree='Master of Business Administration (M.B.A.)', subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin',  ...
# {'person_id_pc': 18580496, 'name': 'Carri Fernandez', 'description': 'I love my job because I can help others achieve their goals. It is a privilege to play a supportive role in the large decision process of buying or selling Real Estate. As my client, you can rely on me to guide you through the process in a concise and comprehensive way.', 'title': '2013 & 2014 President / Board of Directors', 'headline': None, 'city': 'Chula Vista', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=None, company_name=None, seniority_level='CXO', title='2013 & 2014 President / Board of Directors', started_on=datetime.date(2000, 1, 1), ended_on=None), Row(company_id=6910895, company_name='Berkshire Hathaway HomeServices California Properties', seniority_level=None, title='Broker Associate', started_on=datetime.date(1981, 1, 1), ended_on=None), Row(company_id=6910895, company_name='Berkshire Hathaway HomeServices California Properties', seniority_level=None, title='Realtor', started_on=datetime.date(1998, 1, 1), ended_on=None), Row(company_id=110721, company_name='Berkshire Hathaway', seniority_level=None, title='Realtor - Broker Associate', started_on=datetime.date(1998, 9, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='Chula Vista High School', degree=None, subject=None, started_on=datetime.date(1976, 1, 1), ended_on=datetime.date(1980, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/carri-fernandez-6445a817')]}
# {'person_id_pc': 586843, 'name': 'Mario Viviani', 'description': 'My responsibility as Manager of Developer Marketing & Evangelism for Amazon Digital, Apps and Games Services (DAGS) is to lead the team focused on Amazon\'s engagement and outreach with the apps and games developer community in Europe, ensuring that developers are constantly kept up to date with the latest Amazon technologies and services related to devices like Amazon Fire TV, Amazon Fire Tablets and Appstore. I also act as Lead EU Technology Evangelist, attending and presenting at international developer events.\\nBetween 2015 and 2019 I\'ve been the lead Technology Evangelist for Amazon Digital Apps and Games Services in Europe. Since 2019 I lead the Developer Marketing Team EU.\\nI\'m an Android Developer since 2010, and I have published 95+ Android apps on various app stores.\\nIn 2011 I founded the startup Mariux Apps, based in Milan, Italy.\\nAt Mariux Apps my products received 12.000.000+ total downloads and are currently ranked in the Top 100 apps for Personalization and Customization apps in Google Play.\\nI teamed up with other young developers, graphic designers and entrepreneurs to become part of project "Talent Garden" in nothern Italy, a network of Co-Working spaces.\\nI have deep experience with Wearables Development, on Android Wear and Google Glass. I also have experience in Games and Virtual Reality Development (Unity, Oculus VR).\\nAt Mariux Apps I\'ve been also working as Leap Motion developer, and I\'ve done research on Hand Gestures recognition and Hand Gestures UI/UX.\\nI\'ve been nominated Google Developer Expert (GDE) for Android by Google in 2013, and been renewed GDE in 2014 and 2015.\\nI\'m strongly active in the international Android Community, and I partecipate as speaker in a lot of major events worldwide (Google I/O, Droidcon, Android Developer Days, GDG Summits..)\\nSpecialist in: Developer Evangelism, Software Development, Mobile Applications Development, Marketing, Entrepreneurship, Team Leading, Team Management, Community Building, Community Engagement, Developer Partnerships, Games Development, Games Feature Integrations, Virtual Reality development.', 'title': 'Founder & CEO', 'headline': 'Manager, Developer Marketing & Evangelism, EU at Amazon', 'city': 'London', 'region': 'England', 'postal_code': None, 'country': 'GB', 'employments': [Row(company_id=None, company_name=None, seniority_level='CXO', title='Founder & CEO', started_on=datetime.date(2011, 1, 1), ended_on=datetime.date(2015, 9, 1)), Row(company_id=203437, company_name='Amazon', seniority_level=None, title='Technology Evangelist, EU', started_on=datetime.date(2017, 5, 1), ended_on=datetime.date(2019, 7, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Android Mentor', started_on=datetime.date(2014, 4, 1), ended_on=datetime.date(2014, 5, 1)), Row(company_id=203437, company_name='Amazon', seniority_level='Head of ...', title='Head of Developer Evangelism, Worldwide (Apps & Games)', started_on=datetime.date(2021, 2, 1), ended_on=datetime.date(2022, 6, 1)), Row(company_id=None, company_name=None, seniority_level='CXO', title='Co-Founder & CEO', started_on=datetime.date(2014, 5, 1), ended_on=datetime.date(2015, 9, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Google Developer Expert', started_on=datetime.date(2013, 10, 1), ended_on=datetime.date(2015, 9, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Editor', started_on=datetime.date(2010, 5, 1), ended_on=datetime.date(2014, 5, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Mentor', started_on=datetime.date(2013, 6, 1), ended_on=datetime.date(2013, 6, 1)), Row(company_id=203437, company_name='Amazon', seniority_level='Manager', title='Manager, Developer Marketing & Evangelism, EU', started_on=datetime.date(2019, 7, 1), ended_on=datetime.date(2021, 2, 1)), Row(company_id=203437, company_name='Amazon', seniority_l ...
# {'person_id_pc': 1421522, 'name': 'Maria Kavaliova', 'description': '14+ years of Hands-on and Management experience in delivering Machine Learning Solutions and data-driven Analytics for international Financial Services / Fintech / Technology Companies and Markets. From concept to production, Technical Leader and Developer of Predictive models used throughout the entire Customer lifecycle. Credit Risk Management and Predictive Modeling for Underwriting and Account Management, Collection models / Fraud Risk Management for Payments for new and existing Customers / People Analytics and Modeling (Flight Risk) / Marketing and Customer Analytics, Uplift and Propensity Modeling, Customer Acquisition, LTV, Churn and Conversion models. Experienced with B2C and B2B Portfolios and Companies globally (North America, EMEA, APAC and LATAM).', 'title': 'Principal Data Scientist, Global Risk and Data Science', 'headline': 'Staff Data Scientist at Tesla', 'city': 'Atlanta Metropolitan Area', 'region': None, 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=361, company_name='PayPal', seniority_level=None, title='Principal Data Scientist, Global Risk and Data Science', started_on=datetime.date(2016, 2, 1), ended_on=datetime.date(2017, 6, 1)), Row(company_id=351, company_name='Citi', seniority_level='VP', title='Senior Vice President, Global Modeling and Risk Analytics', started_on=datetime.date(2016, 1, 1), ended_on=datetime.date(2016, 2, 1)), Row(company_id=351, company_name='Citi', seniority_level='VP', title='Vice President, Global Modeling and Risk Analytics', started_on=datetime.date(2013, 1, 1), ended_on=datetime.date(2016, 1, 1)), Row(company_id=351, company_name='Citi', seniority_level=None, title='Assistant Vice President, Global Modeling and Risk Analytics', started_on=datetime.date(2011, 4, 1), ended_on=datetime.date(2012, 12, 1)), Row(company_id=1548385, company_name='Priorbank', seniority_level=None, title='Credit Risk Analyst', started_on=datetime.date(2008, 3, 1), ended_on=datetime.date(2010, 7, 1)), Row(company_id=70092, company_name='Oportun', seniority_level=None, title='Principal Data Scientist, Senior Manager', started_on=datetime.date(2017, 6, 1), ended_on=datetime.date(2019, 2, 1)), Row(company_id=6276088, company_name='Smartmob', seniority_level=None, title='Product Marketing Manager, Data Science', started_on=datetime.date(2018, 12, 1), ended_on=None), Row(company_id=1694, company_name='Tesla', seniority_level=None, title='Staff Data Scientist', started_on=datetime.date(2020, 7, 1), ended_on=None), Row(company_id=11667820, company_name='KServicing', seniority_level='Director', title='Director, Data Science', started_on=datetime.date(2020, 1, 1), ended_on=datetime.date(2020, 5, 1)), Row(company_id=11667820, company_name='KServicing', seniority_level=None, title='Data Science Manager, Senior Modeler', started_on=datetime.date(2019, 5, 1), ended_on=datetime.date(2020, 1, 1))], 'institute': [Row(institution_id=192997, institution_name='Belarusian State University', degree="Master's", subject='Applied Mathematics and Computer science / Mathematical Economics', started_on=datetime.date(2003, 1, 1), ended_on=datetime.date(2008, 1, 1)), Row(institution_id=199265, institution_name='Stanford University', degree='Continuing Education class', subject='Cultivating Healthy Company Culture: Building Strong Teams And Engaging Top Talent', started_on=datetime.date(2019, 1, 1), ended_on=datetime.date(2019, 1, 1)), Row(institution_id=77894, institution_name='Udacity', degree='Nanodegree', subject='Machine Learning Engineer', started_on=datetime.date(2018, 1, 1), ended_on=datetime.date(2018, 1, 1)), Row(institution_id=None, institution_name='BSU Lyceum', degree=None, subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/maria-kavaliova-05772232')]}
# {'person_id_pc': 1205136, 'name': 'Ken White', 'description': None, 'title': 'Sales Director - Media and Entertainment - US', 'headline': 'Sales Director - Media & Entertainment', 'city': 'San Francisco', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=4360, company_name='NVIDIA', seniority_level='Director', title='Sales Director - Media and Entertainment - US', started_on=datetime.date(2020, 6, 1), ended_on=None), Row(company_id=40, company_name='Cisco', seniority_level=None, title='Data Center Product Sales Specialist', started_on=datetime.date(2003, 8, 1), ended_on=datetime.date(2011, 11, 1)), Row(company_id=None, company_name=None, seniority_level='Director', title='Sales Director - US West', started_on=datetime.date(2017, 6, 1), ended_on=datetime.date(2020, 6, 1)), Row(company_id=109093, company_name='Stratoscale', seniority_level='Director', title='Sales Director - US West', started_on=datetime.date(2016, 5, 1), ended_on=datetime.date(2017, 6, 1)), Row(company_id=29227, company_name='Nasuni', seniority_level=None, title='Regional Sales Manager', started_on=datetime.date(2012, 2, 1), ended_on=datetime.date(2013, 8, 1)), Row(company_id=38720, company_name='Panzura', seniority_level='Director', title='Strategic Account Director', started_on=datetime.date(2013, 8, 1), ended_on=datetime.date(2016, 4, 1))], 'institute': [Row(institution_id=195422, institution_name='University of Arizona', degree=None, subject=None, started_on=datetime.date(1990, 1, 1), ended_on=datetime.date(1995, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/ken-white-76a5632b')]}
# ...
# {'person_id_pc': 1279614, 'name': 'Ashley McNamara', 'description': 'Currently hiring leadership talent. Please reach out directly: AMcNamara@spotify.com!\\n\\nCurrently fully immersed in the technology market, filling engineering leadership roles for Spotify. We are hiring - come join us!\\n\\nHave lived and worked in the NYC, Boston, and Chicago markets where I built offices from the ground up. I love meeting new people and learning about the latest and greatest companies and technologies!\\n\\nMy primary objective is to build long lasting and credible relationships with clients, business partners, and team members.  The goal is to understand their challenges and initiatives so I can recommend the best solutions to meet their bottom-line employment needs.  Each experience I have had in technology recruiting and sales has left me with a true understanding of the significance of robust relationships when solving business challenges.  This includes providing excellent customer service as an experienced consultative resource.  Ultimately, my success is founded on achieving the right connection for both the candidate and the client.\\n\\nFeel free to connect or shoot me an email (AMcNamara@spotify.com). I am always looking to network and meet new people!', 'title': 'Paralegal', 'headline': 'Senior Technical Recruiting at Spotify, Ex-Peloton And Dropbox, Currently Hiring Leaders for our Engineering Teams', 'city': 'New York', 'region': 'New York', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=323667, company_name='Kasowitz Benson Torres & Friedman LLP', seniority_level=None, title='Paralegal', started_on=datetime.date(2010, 5, 1), ended_on=datetime.date(2011, 9, 1)), Row(company_id=8426881, company_name='ISPOSSIBLE IN TECH', seniority_level='Director', title='Managing Director', started_on=datetime.date(2015, 9, 1), ended_on=datetime.date(2016, 10, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Co-Founder', started_on=datetime.date(2011, 10, 1), ended_on=datetime.date(2016, 11, 1)), Row(company_id=194878, company_name='Trinity College', seniority_level=None, title='Alumni Relations', started_on=datetime.date(2007, 9, 1), ended_on=datetime.date(2010, 5, 1)), Row(company_id=88365, company_name='Peloton', seniority_level=None, title='Technical Recruiting for Engineering Leadership', started_on=datetime.date(2021, 3, 1), ended_on=datetime.date(2022, 3, 1)), Row(company_id=506, company_name='Dropbox', seniority_level=None, title='Technical Recruiting and Sourcing for Engineering Leadership', started_on=datetime.date(2016, 3, 1), ended_on=datetime.date(2021, 3, 1)), Row(company_id=49545, company_name='Talener', seniority_level='Manager', title='Group Manager', started_on=datetime.date(2013, 7, 1), ended_on=datetime.date(2015, 9, 1)), Row(company_id=49545, company_name='Talener', seniority_level='Manager', title='Lead Relationship Manager', started_on=datetime.date(2012, 6, 1), ended_on=datetime.date(2013, 7, 1)), Row(company_id=49545, company_name='Talener', seniority_level='Manager', title='Relationship Manager', started_on=datetime.date(2011, 9, 1), ended_on=datetime.date(2012, 5, 1)), Row(company_id=4053, company_name='Spotify', seniority_level=None, title='Senior Technical Recruiter for Engineering Leadership and Executive Recruiting', started_on=datetime.date(2022, 3, 1), ended_on=None)], 'institute': [Row(institution_id=None, institution_name='Trinity College-Hartford', degree='Masters', subject='Public Policy and Law', started_on=datetime.date(2007, 1, 1), ended_on=datetime.date(2009, 1, 1)), Row(institution_id=None, institution_name='Trinity College-Hartford', degree='BA', subject='Political Science, double minor Legal Studies and Italian Studies', started_on=datetime.date(2003, 1, 1), ended_on=datetime.date(2007, 1, 1)), Row(institution_id=None, institution_name='Branford High', degree=None, subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='h ...
# {'person_id_pc': 368727, 'name': 'William Bencze', 'description': 'Innovative and resourceful technical principal and engineering manager. Extensive technical expertise in satellite navigation and location systems, RF systems, feedback control, signal processing & estimation, analog low-noise electronics design, digital system design, inertial instrumentation and measurement, spacecraft systems and mission design, and systems engineering.\\nStrong leader and senior engineering manager with a track record of accomplishments leading both to highly productive multi-disciplinary technical teams and to successful product deliveries for military and civilian government customers. Passionate about forming and coaching tight, high-performance multi-disciplinary engineering teams to attack the most challenging technical problems.', 'title': 'Design Engineer', 'headline': 'Software Engineering Manager at Apple', 'city': 'San Francisco', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=10347, company_name='National Semiconductor', seniority_level=None, title='Design Engineer', started_on=datetime.date(1989, 6, 1), ended_on=datetime.date(1989, 10, 1)), Row(company_id=295718, company_name='Coherent Navigation', seniority_level='VP', title='Co-Founder and Vice President of Engineering', started_on=datetime.date(2008, 8, 1), ended_on=datetime.date(2014, 9, 1)), Row(company_id=199265, company_name='Stanford University', seniority_level=None, title='Program Manager - Spacecraft mission operations', started_on=datetime.date(2001, 1, 1), ended_on=datetime.date(2008, 5, 1)), Row(company_id=199265, company_name='Stanford University', seniority_level=None, title='Senior Research Engineer, Manager - Spaceflight instrumentation', started_on=datetime.date(1996, 8, 1), ended_on=datetime.date(2001, 1, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='R&D Engineer - Semiconductors', started_on=datetime.date(1990, 6, 1), ended_on=datetime.date(1990, 9, 1)), Row(company_id=1660, company_name='Apple', seniority_level=None, title='GNSS Platform Software Engineering Manager', started_on=datetime.date(2017, 10, 1), ended_on=None), Row(company_id=1660, company_name='Apple', seniority_level=None, title='GNSS Platform Software Engineer', started_on=datetime.date(2014, 9, 1), ended_on=datetime.date(2017, 9, 1)), Row(company_id=4645, company_name='The Boeing Company', seniority_level=None, title='Consultant - Satellite navigation algorithm R&D', started_on=datetime.date(2006, 6, 1), ended_on=datetime.date(2008, 7, 1))], 'institute': [Row(institution_id=199265, institution_name='Stanford University', degree='BS', subject=None, started_on=None, ended_on=None), Row(institution_id=199265, institution_name='Stanford University', degree='PhD', subject=None, started_on=None, ended_on=None), Row(institution_id=199265, institution_name='Stanford Universtiy', degree='MS', subject=None, started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/wjbencze'), Row(url_type='crunchbase', url='https://www.crunchbase.com/person/william-bencze'), Row(url_type='github', url='github.com/bencze')]}
# {'person_id_pc': 625782, 'name': 'Sherisse Pham', 'description': "Award winning CNN reporter. I cover tech and business in Hong Kong -- got a tip or a story you'd like to share? Hit me up at sherisse [dot] pham [at] cnn [dot] com.", 'title': 'Frank Reynolds Fellow', 'headline': 'CNN tech and business reporter', 'city': None, 'region': None, 'postal_code': None, 'country': 'HK', 'employments': [Row(company_id=2388, company_name='ABC News', seniority_level=None, title='Frank Reynolds Fellow', started_on=datetime.date(2010, 9, 1), ended_on=datetime.date(2010, 12, 1)), Row(company_id=2388, company_name='ABC News', seniority_level=None, title='Producer/Reporter', started_on=datetime.date(2011, 6, 1), ended_on=datetime.date(2013, 2, 1)), Row(company_id=10688173, company_name='Wwd - Worldwide Devices Corporation', seniority_level=None, title='Contributing Writer', started_on=datetime.date(2007, 1, 1), ended_on=datetime.date(2009, 8, 1)), Row(company_id=7016, company_name='CNN', seniority_level=None, title='Intern', started_on=datetime.date(2008, 4, 1), ended_on=datetime.date(2008, 8, 1)), Row(company_id=7016, company_name='CNN', seniority_level=None, title='Reporter', started_on=datetime.date(2016, 10, 1), ended_on=datetime.date(2020, 12, 1)), Row(company_id=7016, company_name='CNN', seniority_level=None, title='Producer', started_on=datetime.date(2013, 2, 1), ended_on=datetime.date(2016, 10, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Freelance Journalist', started_on=datetime.date(2011, 1, 1), ended_on=datetime.date(2011, 5, 1)), Row(company_id=7142918, company_name='Embassy Of Canada | Ambassade Du Canada', seniority_level=None, title='Visa Officer', started_on=datetime.date(2005, 4, 1), ended_on=datetime.date(2007, 5, 1)), Row(company_id=7331543, company_name='Columbia University  Graduate School Of Journalism', seniority_level=None, title='M.S. Student', started_on=datetime.date(2009, 1, 1), ended_on=datetime.date(2010, 1, 1)), Row(company_id=9199669, company_name='News21', seniority_level=None, title='News21 Fellow', started_on=datetime.date(2010, 3, 1), ended_on=datetime.date(2010, 7, 1)), Row(company_id=2289, company_name='Netflix', seniority_level='Head of ...', title='Head Of Internal Communications, APAC', started_on=datetime.date(2021, 2, 1), ended_on=None)], 'institute': [Row(institution_id=143256, institution_name='Columbia University Graduate School of Journalism', degree='MS', subject='Broadcast', started_on=None, ended_on=None)], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/sherisse-pham-9049b516'), Row(url_type='crunchbase', url='https://crunchbase.com/person/sherisse-pham')]}
# {'person_id_pc': 28729993, 'name': 'Zora Wolter', 'description': '* Award-winning, innovative producer for films, tv and other content for global audiences\\n * 20 years herder of creative people, clients, projects, budgets and schedules\\n * Visionary with extensive knowledge, expertise and perseverance\\n * Excels in strategic development and partnerships\\n * Capacity for developing, tracking and reconciling multi-million dollar budgets and leading large teams\\n * A highly successful hybrid between the creative and strategic side of storytelling and content production\\n * Charismatic and excellent communicator \\n * International production experience across Europe, North Africa, New Zealand\\n * Strong social engagement and involvement in non-profit organization\\n * Personal passion for environmental protection and sustainable living', 'title': 'Creative Producer', 'headline': None, 'city': 'Los Angeles', 'region': 'California', 'postal_code': None, 'country': 'US', 'employments': [Row(company_id=1660, company_name='Apple', seniority_level=None, title='Creative Producer', started_on=datetime.date(2019, 2, 1), ended_on=None), Row(company_id=None, company_name=None, seniority_level='Director', title='Foundation Director', started_on=datetime.date(2015, 11, 1), ended_on=datetime.date(2016, 9, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Founder', started_on=datetime.date(2018, 4, 1), ended_on=None), Row(company_id=None, company_name=None, seniority_level=None, title='Line Producer', started_on=datetime.date(2010, 1, 1), ended_on=datetime.date(2011, 12, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Line Producer', started_on=datetime.date(2009, 1, 1), ended_on=datetime.date(2009, 12, 1)), Row(company_id=9617170, company_name='Prometheus Entertainment', seniority_level=None, title='Producer', started_on=datetime.date(2011, 11, 1), ended_on=datetime.date(2012, 7, 1)), Row(company_id=None, company_name=None, seniority_level=None, title='Producer', started_on=datetime.date(2000, 1, 1), ended_on=None), Row(company_id=6216250, company_name='Hamblin Imagery Limited', seniority_level=None, title='Producer', started_on=datetime.date(2014, 7, 1), ended_on=datetime.date(2016, 10, 1)), Row(company_id=9617170, company_name='Prometheus Entertainment', seniority_level=None, title='Producer', started_on=datetime.date(2008, 1, 1), ended_on=datetime.date(2009, 1, 1)), Row(company_id=317102, company_name='Red Bull Media House', seniority_level=None, title='Producer / Line Producer', started_on=datetime.date(2014, 3, 1), ended_on=datetime.date(2016, 11, 1)), Row(company_id=317102, company_name='Red Bull Media House', seniority_level=None, title='Producer / Line Producer', started_on=datetime.date(2014, 4, 1), ended_on=datetime.date(2015, 3, 1)), Row(company_id=1661631, company_name='WM Technology', seniority_level='VP', title='VP of Production & Development WM TV', started_on=datetime.date(2017, 5, 1), ended_on=datetime.date(2017, 10, 1))], 'institute': [Row(institution_id=None, institution_name='Columbia College Chicago', degree='Bachelors;Bachelor Of Arts', subject='Screenwriting', started_on=datetime.date(1993, 1, 1), ended_on=datetime.date(1996, 1, 1))], 'urls': [Row(url_type='linkedin', url='https://www.linkedin.com/in/zora-a-wolter'), Row(url_type='facebook', url='facebook.com/zora.wolter')]}

# %%
result_df.printSchema()
# Out:
# root
#  |-- person_id_pc: long (nullable = true)
#  |-- created_at_pc: string (nullable = false)
#  |-- customer_id_pc: string (nullable = false)
#  |-- id_pc: string (nullable = false)
#  |-- updated_at_pc: string (nullable = false)
#  |-- person_id_ppl: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address_ppl: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- seniority_level: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- headline: string (nullable = true)
#  |-- started_on: date (nullable = true)
#  |-- ended_on: date (nullable = true)
#  |-- company_id: long (nullable = true)
#  |-- created_at_ppl: timestamp (nullable = true)
#  |-- updated_at_ppl: timestamp (nullable = true)
#  |-- institute: array (nullable = false)
#  |    |-- element: struct (containsNull = false)
#  |    |    |-- institution_id: long (nullable = true)
#  |    |    |-- institution_name: string (nullable = true)
#  |    |    |-- degree: string (nullable = true)
#  |    |    |-- subject: string (nullable = true)
#  |    |    |-- started_on: date (nullable = true)
#  |    |    |-- ended_on: date (nullable = true)
#  |-- latest_edu_created_at: timestamp (nullable = true)
#  |-- latest_edu_updated_at: timestamp (nullable = true)
#  |-- employments: array (nullable = false)
#  |    |-- element: struct (containsNull = false)
#  |    |    |-- company_id: long (nullable = true)
#  |    |    |-- company_name: string (nullable = true)
#  |    |    |-- seniority_level: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- started_on: date (nullable = true)
#  |    |    |-- ended_on: date (nullable = true)
#  |-- latest_emp_created_at: timestamp (nullable = true)
#  |-- latest_emp_updated_at: timestamp (nullable = true)
#  |-- urls: array (nullable = false)
#  |    |-- element: struct (containsNull = false)
#  |    |    |-- url_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- latest_url_created_at: timestamp (nullable = true)
#  |-- latest_url_updated_at: timestamp (nullable = true)

# %%
#result_df = result_df.drop("created_at")
# Write the DataFrame to a Parquet file, overwriting if it already exists
result_df.write.mode("overwrite").parquet("final_output/df.parquet")

# %%
# Read the parquet file and create a new DataFrame
new_df = spark.read.parquet("final_output/df.parquet")

# Display a row
new_df.show(10)
# Out:
# +------------+--------------------+--------------------+-----+--------------------+-------------+----------------+-----------+-------------+----------+-----------+---------+--------------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |person_id_pc|       created_at_pc|      customer_id_pc|id_pc|       updated_at_pc|person_id_ppl|            name|address_ppl|         city|    region|postal_code|  country|        company_name|seniority_level|         description|               title|            headline|started_on|  ended_on|company_id|      created_at_ppl|      updated_at_ppl|           institute|latest_edu_created_at|latest_edu_updated_at|         employments|latest_emp_created_at|latest_emp_updated_at|                urls|latest_url_created_at|latest_url_updated_at|
# +------------+--------------------+--------------------+-----+--------------------+-------------+----------------+-----------+-------------+----------+-----------+---------+--------------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# |   949256266|2024-02-09 12:07:...|7538cb11-1c23-4c7...|   60|2024-02-09 12:07:...|    949256266|     Vivian Weng|       NULL|         NULL|      NULL|       NULL|SINGAPORE|            DBS Bank|             VP|                NULL|Vice President, I...|Product Design, S...|2016-07-01|2019-04-01|     15861|2023-12-11 06:18:...|                NULL|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|[{15861, DBS Bank...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    48171849|2024-01-16 13:29:...|7538cb11-1c23-4c7...|    5|2024-01-16 13:29:...|     48171849| Courtney Turner|       NULL|       Toledo|      Ohio|       NULL|       US|               Apple|           NULL|The search for so...|    Creative Trainer|                NULL|2018-03-01|      NULL|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, The Unive...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, NU...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    74707094|2024-02-09 12:08:...|7538cb11-1c23-4c7...|   91|2024-02-09 12:08:...|     74707094|   Katie Richter|       NULL|       Austin|     Texas|       NULL|       US|    Casting Networks|           NULL|Retail Business S...|BUSINESS DEVELOPMENT|                NULL|2010-05-01|2011-04-01|    601281|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Rhodes Co...| 2023-12-11 06:18:...|                 NULL|[{601281, Casting...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |     1373896|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   40|2024-02-07 11:24:...|      1373896| Chelsea Kanduth|       NULL|      Chicago|  Illinois|       NULL|       US|         Red Lobster|           NULL|Experienced Accou...|Front-Line Sales,...|Advertising Guru ...|2014-05-01|2015-12-01|    429133|2023-12-11 06:18:...|2023-10-26 15:57:...|[{6356260, St. Cl...| 2023-12-11 06:18:...|                 NULL|[{429133, Red Lob...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    51432999|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  105|2024-02-09 12:08:...|     51432999|    Juan Sanchez|       NULL|        Boise|     Idaho|       NULL|       US|               Apple|       Director|Art Director at A...|        Art Director|                NULL|      NULL|      NULL|      1660|2023-12-11 06:18:...|2023-10-18 23:07:...|[{NULL, Minico Hi...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, Di...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |     1420981|2024-02-07 11:24:...|7538cb11-1c23-4c7...|   42|2024-02-07 11:24:...|      1420981|Jasmine Scofield|       NULL|  Santa Clara|California|       NULL|       US|    DHL Supply Chain|           NULL|6+ years in End-T...|Administrative As...|Senior Payroll An...|2015-08-01|2016-10-01|   1524224|2023-12-11 06:18:...|2023-10-26 15:57:...|[{193734, Diablo ...| 2023-12-11 06:18:...|                 NULL|[{1524224, DHL Su...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    22565708|2024-02-13 06:38:...|7538cb11-1c23-4c7...|  144|2024-02-13 06:38:...|     22565708|        Tim Wong|       NULL|     Danville|California|       NULL|       US|           HFTrading|            CXO|Execution fanatic...|Chief Marketing O...|Technical Marketi...|2013-12-01|2014-07-01|   1334078|2023-12-11 06:18:...|2023-11-01 07:37:...|[{NULL, At&T Scho...| 2023-12-11 06:18:...|                 NULL|[{1334078, HFTrad...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    71726687|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  102|2024-02-09 12:08:...|     71726687| Katherine Hicks|       NULL|  Bay Village|      Ohio|       NULL|       US|Girl Scouts of No...|       Director|Results Driven, C...|        Art Director|                NULL|2007-06-01|2010-08-01|    145458|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Barnard C...| 2023-12-11 06:18:...|                 NULL|[{145458, Girl Sc...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    20891932|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  122|2024-02-09 12:08:...|     20891932| Cynthia Collins|       NULL|San Francisco|California|       NULL|       US|               Apple|           NULL|18 years of progr...|Customer Relation...|                NULL|1985-01-01|1986-01-01|      1660|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Universit...| 2023-12-11 06:18:...|                 NULL|[{1660, Apple, NU...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# |    22355698|2024-02-09 12:08:...|7538cb11-1c23-4c7...|  114|2024-02-09 12:08:...|     22355698|  Ritchie Lozada|       NULL|San Francisco|California|       NULL|       US|                NULL|        Manager|Passion for compl...|Asst. General Man...|                NULL|1994-01-01|1996-01-01|      NULL|2023-12-11 06:18:...|2023-10-14 21:35:...|[{NULL, Ateneo De...| 2023-12-11 06:18:...|                 NULL|[{NULL, NULL, Man...| 2023-12-11 06:18:...|                 NULL|[{linkedin, https...| 2023-12-11 06:18:...|                 NULL|
# +------------+--------------------+--------------------+-----+--------------------+-------------+----------------+-----------+-------------+----------+-----------+---------+--------------------+---------------+--------------------+--------------------+--------------------+----------+----------+----------+--------------------+--------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+--------------------+---------------------+---------------------+
# only showing top 10 rows

# %%
print(type(new_df))
new_df.printSchema()
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# root
#  |-- person_id_pc: long (nullable = true)
#  |-- created_at_pc: string (nullable = true)
#  |-- customer_id_pc: string (nullable = true)
#  |-- id_pc: string (nullable = true)
#  |-- updated_at_pc: string (nullable = true)
#  |-- person_id_ppl: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address_ppl: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- seniority_level: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- headline: string (nullable = true)
#  |-- started_on: date (nullable = true)
#  |-- ended_on: date (nullable = true)
#  |-- company_id: long (nullable = true)
#  |-- created_at_ppl: timestamp (nullable = true)
#  |-- updated_at_ppl: timestamp (nullable = true)
#  |-- institute: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- institution_id: long (nullable = true)
#  |    |    |-- institution_name: string (nullable = true)
#  |    |    |-- degree: string (nullable = true)
#  |    |    |-- subject: string (nullable = true)
#  |    |    |-- started_on: date (nullable = true)
#  |    |    |-- ended_on: date (nullable = true)
#  |-- latest_edu_created_at: timestamp (nullable = true)
#  |-- latest_edu_updated_at: timestamp (nullable = true)
#  |-- employments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- company_id: long (nullable = true)
#  |    |    |-- company_name: string (nullable = true)
#  |    |    |-- seniority_level: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- started_on: date (nullable = true)
#  |    |    |-- ended_on: date (nullable = true)
#  |-- latest_emp_created_at: timestamp (nullable = true)
#  |-- latest_emp_updated_at: timestamp (nullable = true)
#  |-- urls: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- url_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- latest_url_created_at: timestamp (nullable = true)
#  |-- latest_url_updated_at: timestamp (nullable = true)

# %%
# Assuming your DataFrame is named 'new_df'
# Select the columns you want to concatenate into a single string
columns_to_combine = ["person_id_pc", "created_at_pc", "customer_id_pc", "id_pc", "updated_at_pc", "person_id_ppl",
                      "name", "address_ppl", "city", "region", "postal_code", "country", "company_name",
                      "seniority_level", "description", "title", "headline", "started_on", "ended_on", "company_id",
                      "created_at_ppl", "updated_at_ppl", "institute", "latest_edu_created_at", "latest_edu_updated_at",
                      "employments", "latest_emp_created_at", "latest_emp_updated_at", "urls", "latest_url_created_at",
                      "latest_url_updated_at"]

# Combine selected columns into a single column
combined_column = concat_ws(", ", *[col(col_name).cast("string") for col_name in columns_to_combine])

# Add the combined column to the DataFrame
df_with_combined = new_df.withColumn("combined_row", combined_column)

# Show the DataFrame with the combined row
df_with_combined.select("combined_row").show(1,truncate=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 11
#       3 columns_to_combine = ["person_id_pc", "created_at_pc", "customer_id_pc", "id_pc", "updated_at_pc", "person_id_ppl",
#       4                       "name", "address_ppl", "city", "region", "postal_code", "country", "company_name",
#       5                       "seniority_level", "description", "title", "headline", "started_on", "ended_on", "company_id",
#       6                       "created_at_ppl", "updated_at_ppl", "institute", "latest_edu_created_at", "latest_edu_updated_at",
#       7                       "employments", "latest_emp_created_at", "latest_emp_updated_at", "urls", "latest_url_created_at",
#       8                       "latest_url_updated_at"]
#      10 # Combine selected columns into a single column
# ---> 11 combined_column = concat_ws(", ", *[col(col_name).cast("string") for col_name in columns_to_combine])
#      13 # Add the combined column to the DataFrame
#      14 df_with_combined = new_df.withColumn("combined_row", combined_column)
#
# NameError: name 'concat_ws' is not defined

# %%
'''from pyspark.sql.functions import col, explode

# Flatten the 'urls' array of structs
urls_df = new_df.select(
    col("person_id_pc"),
    explode("urls").alias("url_struct")
).select(
    col("person_id_pc"),
    col("url_struct.url_type").alias("url_type"),
    col("url_struct.url").alias("url")
)

# Flatten the 'employments' array of structs
employments_df = new_df.select(
    col("person_id_pc"),
    explode("employments").alias("employment_struct")
).select(
    col("person_id_pc"),
    col("employment_struct.company_id").alias("company_id_emp"),
    col("employment_struct.company_name").alias("company_name_emp"),
    col("employment_struct.seniority_level").alias("seniority_level_emp"),
    col("employment_struct.title").alias("employment_title_emp"),
    col("employment_struct.started_on").alias("employment_started_on_emp"),
    col("employment_struct.ended_on").alias("employment_ended_on_emp")
)

# Flatten the 'institute' array of structs
institute_df = new_df.select(
    col("person_id_pc"),
    explode("institute").alias("institute_struct")
).select(
    col("institute_struct.institution_id").alias("institution_id_inst"),
    col("institute_struct.institution_name").alias("institution_name_inst"),
    col("institute_struct.degree").alias("degree_inst"),
    col("institute_struct.subject").alias("subject_inst"),
    col("institute_struct.started_on").alias("institute_started_on_inst"),
    col("institute_struct.ended_on").alias("institute_ended_on_inst")
)

# Join all the flattened DataFrames
flattened_df = new_df.join(urls_df, on="person_id_pc", how="left") \
    .join(employments_df, on=["person_id_pc"], how="left") \
    .join(institute_df, on=["person_id_pc"], how="left")

# Write flattened DataFrame to CSV
flattened_df.coalesce(1).write.csv("output.csv", header=True)'''
# Out:
# 'from pyspark.sql.functions import col, explode\n\n# Flatten the \'urls\' array of structs\nurls_df = new_df.select(\n    col("person_id_pc"),\n    explode("urls").alias("url_struct")\n).select(\n    col("person_id_pc"),\n    col("url_struct.url_type").alias("url_type"),\n    col("url_struct.url").alias("url")\n)\n\n# Flatten the \'employments\' array of structs\nemployments_df = new_df.select(\n    col("person_id_pc"),\n    explode("employments").alias("employment_struct")\n).select(\n    col("person_id_pc"),\n    col("employment_struct.company_id").alias("company_id_emp"),\n    col("employment_struct.company_name").alias("company_name_emp"),\n    col("employment_struct.seniority_level").alias("seniority_level_emp"),\n    col("employment_struct.title").alias("employment_title_emp"),\n    col("employment_struct.started_on").alias("employment_started_on_emp"),\n    col("employment_struct.ended_on").alias("employment_ended_on_emp")\n)\n\n# Flatten the \'institute\' array of structs\ninstitute_df = new_df.select(\n    col("person_id_pc"),\n    explode("institute").alias("institute_struct")\n).select(\n    col("institute_struct.institution_id").alias("institution_id_inst"),\n    col("institute_struct.institution_name").alias("institution_name_inst"),\n    col("institute_struct.degree").alias("degree_inst"),\n    col("institute_struct.subject").alias("subject_inst"),\n    col("institute_struct.started_on").alias("institute_started_on_inst"),\n    col("institute_struct.ended_on").alias("institute_ended_on_inst")\n)\n\n# Join all the flattened DataFrames\nflattened_df = new_df.join(urls_df, on="person_id_pc", how="left")     .join(employments_df, on=["person_id_pc"], how="left")     .join(institute_df, on=["person_id_pc"], how="left")\n\n# Write flattened DataFrame to CSV\nflattened_df.coalesce(1).write.csv("output.csv", header=True)'
